# %% [markdown]
# # nanochat base train + eval notebook
#
# Notebook-first workflow for `scripts/base_train.py` **and** `scripts/base_eval.py` without manual CLI typing.

# %% [markdown]
# ## 1) Configure training
# Set token budget + evaluation cadence. CORE eval is enabled by default via `core_metric_every`.

# %%
import torch._dynamo
torch._dynamo.disable()

# %%
from math import ceil

TRAINING_CONFIG = {
    # Logging/runtime
    'run': 'nb-base-train',
    # 'data_dir': None,#"/kaggle/working/dataset",
    'checkpoints_dir': "base_checkpoints",
    'device_type': '',  # ''=autodetect, or set 'cuda'/'cpu'/'mps'
    # 'parallel': "dp",

    # Model
    'depth': 8, #20,
    'aspect_ratio': 64,
    'head_dim': 16, #128,
    'max_seq_len': 64,#2048,
    'window_pattern': 'SSSL',


    # Batch + training horizon
    'device_batch_size': 8,
    'total_batch_size': 524288//64,  # in tokens
    'training_tokens': 5000 * (524288//64),  # <-- edit this to control total training budget

    # Optimization
    'embedding_lr': 0.3,
    'unembedding_lr': 0.004,
    'weight_decay': 0.2,
    'matrix_lr': 0.02,
    'scalar_lr': 0.5,
    'adam_beta1': 0.8,
    'adam_beta2': 0.95,
    'warmup_ratio': 0.0,
    'warmdown_ratio': 0.5,
    'final_lr_frac': 0.0,
    "moe_use_abs_pos_embed": True,

    # Evaluation/checkpoint cadence
    'eval_every': 1000,#250,
    'eval_tokens': 2 * 524288,
    'core_metric_every': -1,
    'core_metric_max_per_task': 500,
    'sample_every': 500,
    'save_every': 500,

    # Extras
    'resume_from_step': -1,
    'model_tag': 'nb_d20',
    'fp8': False,
    'fp8_recipe': 'tensorwise',
}


TRAINING_CONFIG['num_iterations'] = ceil(TRAINING_CONFIG['training_tokens'] / TRAINING_CONFIG['total_batch_size'])
print('Planned iterations:', TRAINING_CONFIG['num_iterations'])
print('Planned tokens   :', TRAINING_CONFIG['num_iterations'] * TRAINING_CONFIG['total_batch_size'])
print('CORE in training?:', TRAINING_CONFIG['core_metric_every'])
# Out:
# Planned iterations: 50
# Planned tokens   : 409600
# CORE in training?: -1

# %% [markdown]
# ## 2) Convert config to argv for base_train

# %%
def base_train_argv(cfg: dict) -> list[str]:
    flag_map = {
        'run': '--run', 'device_type': '--device-type',
        'data_dir': '--data-dir', 'checkpoints_dir': '--checkpoints-dir',
        'depth': '--depth', 'aspect_ratio': '--aspect-ratio', 'head_dim': '--head-dim',
        'max_seq_len': '--max-seq-len', 'window_pattern': '--window-pattern',
        'num_iterations': '--num-iterations',
        'device_batch_size': '--device-batch-size', 'total_batch_size': '--total-batch-size',
        'embedding_lr': '--embedding-lr', 'unembedding_lr': '--unembedding-lr',
        'weight_decay': '--weight-decay', 'matrix_lr': '--matrix-lr', 'scalar_lr': '--scalar-lr',
        'adam_beta1': '--adam-beta1', 'adam_beta2': '--adam-beta2',
        'warmup_ratio': '--warmup-ratio', 'warmdown_ratio': '--warmdown-ratio', 'final_lr_frac': '--final-lr-frac',
        'resume_from_step': '--resume-from-step',
        'eval_every': '--eval-every', 'eval_tokens': '--eval-tokens',
        'core_metric_every': '--core-metric-every', 'core_metric_max_per_task': '--core-metric-max-per-task',
        'sample_every': '--sample-every', 'save_every': '--save-every',
        'model_tag': '--model-tag', 'fp8_recipe': '--fp8-recipe',
    }
    argv = ['scripts.base_train']
    if cfg.get('fp8', False):
        argv.append('--fp8')
    for k, flag in flag_map.items():
        if k in cfg:
            argv.extend([flag, str(cfg[k])])
    return argv

train_argv = base_train_argv(TRAINING_CONFIG)
print(' '.join(train_argv[:14]), '...')
# Out:
# scripts.base_train --run nb-base-train --device-type  --checkpoints-dir base_checkpoints --depth 8 --aspect-ratio 64 --head-dim 16 --max-seq-len ...

# %% [markdown]
# ## 3) Run base_train (includes bpb eval + CORE eval per cadence)
# `core_metric_every` and `eval_every` control in-training evaluation.

# %%
# !python -m nanochat.dataset -n 500
# Out:
# Downloading 51 shards using 4 workers...
# Target directory: /root/.cache/nanochat/base_data_climbmix
#
# Downloading shard_00000.parquet...
# Downloading shard_00004.parquet...
# Downloading shard_00008.parquet...
# Downloading shard_00012.parquet...
# Successfully downloaded shard_00012.parquet
# Downloading shard_00013.parquet...
# Successfully downloaded shard_00008.parquet
# Downloading shard_00009.parquet...
# Successfully downloaded shard_00000.parquet
# Downloading shard_00001.parquet...
# Successfully downloaded shard_00004.parquet
# Downloading shard_00005.parquet...
# Successfully downloaded shard_00009.parquet
# Downloading shard_00010.parquet...
# Successfully downloaded shard_00001.parquet
# Downloading shard_00002.parquet...
# Successfully downloaded shard_00013.parquet
# Downloading shard_00014.parquet...
# Successfully downloaded shard_00005.parquet
# Downloading shard_00006.parquet...
# Successfully downloaded shard_00010.parquet
# Downloading shard_00011.parquet...
# Successfully downloaded shard_00002.parquet
# Downloading shard_00003.parquet...
# Successfully downloaded shard_00014.parquet
# Downloading shard_00015.parquet...
# Successfully downloaded shard_00006.parquet
# Downloading shard_00007.parquet...
# Successfully downloaded shard_00003.parquet
# Downloading shard_00016.parquet...
# Successfully downloaded shard_00011.parquet
# Downloading shard_00020.parquet...
# Successfully downloaded shard_00015.parquet
# Downloading shard_00024.parquet...
# Successfully downloaded shard_00007.parquet
# Downloading shard_00028.parquet...
# Successfully downloaded shard_00016.parquet
# Downloading shard_00017.parquet...
# Successfully downloaded shard_00024.parquet
# Downloading shard_00025.parquet...
# Successfully downloaded shard_00020.parquet
# Downloading shard_00021.parquet...
# Successfully downloaded shard_00028.parquet
# Downloading shard_00029.parquet...
# Successfully downloaded shard_00017.parquet
# Downloading shard_00018.parquet...
# Successfully downloaded shard_00025.parquet
# Downloading shard_00026.parquet...
# Successfully downloaded shard_00029.parquet
# Downloading shard_00030.parquet...
# Successfully downloaded shard_00021.parquet
# Downloading shard_00022.parquet...
# Successfully downloaded shard_00018.parquet
# Downloading shard_00019.parquet...
# Successfully downloaded shard_00026.parquet
# Downloading shard_00027.parquet...
# Successfully downloaded shard_00030.parquet
# Downloading shard_00031.parquet...
# Successfully downloaded shard_00022.parquet
# Downloading shard_00023.parquet...
# Successfully downloaded shard_00027.parquet
# Downloading shard_00032.parquet...
# Successfully downloaded shard_00019.parquet
# Downloading shard_00036.parquet...
# Successfully downloaded shard_00031.parquet
# Downloading shard_00040.parquet...
# Successfully downloaded shard_00023.parquet
# Downloading shard_00044.parquet...
# Successfully downloaded shard_00036.parquet
# Downloading shard_00037.parquet...
# Successfully downloaded shard_00032.parquet
# Downloading shard_00033.parquet...
# Successfully downloaded shard_00040.parquet
# Downloading shard_00041.parquet...
# Successfully downloaded shard_00044.parquet
# Downloading shard_00045.parquet...
# Successfully downloaded shard_00033.parquet
# Downloading shard_00034.parquet...
# Successfully downloaded shard_00037.parquet
# Downloading shard_00038.parquet...
# Successfully downloaded shard_00041.parquet
# Downloading shard_00042.parquet...
# Successfully downloaded shard_00045.parquet
# Downloading shard_00046.parquet...
# Successfully downloaded shard_00034.parquet
# Downloading shard_00035.parquet...
# Successfully downloaded shard_00042.parquet
# Downloading shard_00043.parquet...
# Successfully downloaded shard_00038.parquet
# Downloading shard_00039.parquet...
# Successfully downloaded shard_00035.parquet
# Downloading shard_00048.parquet...
# Successfully downloaded shard_00046.parquet
# Downloading shard_00047.parquet...
# Successfully downloaded shard_00039.parquet
# Successfully downloaded shard_00043.parquet
# Successfully downloaded shard_00048.parquet
# Downloading shard_00049.parquet...
# Successfully downloaded shard_00047.parquet
# Successfully downloaded shard_00049.parquet
# Downloading shard_06542.parquet...
# Successfully downloaded shard_06542.parquet
# Done! Downloaded: 51/51 shards to /root/.cache/nanochat/base_data_climbmix

# %%
"""
Train a tokenizer using our own BPE Tokenizer library.
In the style of GPT-4 tokenizer.
"""
import os
import time
from nanochat.tokenizer import RustBPETokenizer
from nanochat.common import get_base_dir
from nanochat.dataset import parquets_iter_batched
import torch
# -----------------------------------------------------------------------------
# Parse command line arguments

max_chars = 2_000_000_000
doc_cap = 10_000
vocab_size = 32768

print(f"max_chars: {max_chars:,}")
print(f"doc_cap: {doc_cap:,}")
print(f"vocab_size: {vocab_size:,}")

# -----------------------------------------------------------------------------
# Text iterator

def text_iterator():
    """
    1) Flatten the batches into a single iterator
    2) Crop every document to doc_cap characters
    3) Break when we've seen max_chars characters
    """
    nchars = 0
    for batch in parquets_iter_batched(split="train"):
        for doc in batch:
            doc_text = doc
            if len(doc_text) > doc_cap:
                doc_text = doc_text[:doc_cap]
            nchars += len(doc_text)
            yield doc_text
            if nchars > max_chars:
                return
text_iter = text_iterator()

# -----------------------------------------------------------------------------
# Train the tokenizer
t0 = time.time()
tokenizer = RustBPETokenizer.train_from_iterator(text_iter, vocab_size)
t1 = time.time()
train_time = t1 - t0
print(f"Training time: {train_time:.2f}s")

# -----------------------------------------------------------------------------
# Save the tokenizer to disk
base_dir = get_base_dir()
tokenizer_dir = os.path.join(base_dir, "tokenizer")
tokenizer.save(tokenizer_dir)

# -----------------------------------------------------------------------------
# Quick inline sanity check
test_text = """Hello world! This is a test.
Numbers: 123, 4567, 89
Contractions: I'm, you're, it's
Special chars: @#$%^&*()
Unicode: 你好世界 🌍"""
encoded = tokenizer.encode(test_text)
decoded = tokenizer.decode(encoded)
assert decoded == test_text

# -----------------------------------------------------------------------------
# One more thing: we wish to cache a mapping from token id to number of bytes of that token
# for efficient evaluation of bits per byte. Unlike the typical mean loss, this
# allows us to report a loss that is invariant to the vocab size of the tokenizer.
# The bits per byte on the validation set is then one of the primary metrics we care about.
vocab_size = tokenizer.get_vocab_size()
special_set = set(tokenizer.get_special_tokens())
token_strings = [tokenizer.decode([token_id]) for token_id in range(vocab_size)]
token_bytes = []
for token_id in range(vocab_size):
    token_str = token_strings[token_id] # the Python string representation of this token
    if token_str in special_set:
        token_bytes.append(0) # special characters are not counted
    else:
        id_bytes = len(token_str.encode("utf-8")) # number of bytes that make up this token
        token_bytes.append(id_bytes)
token_bytes = torch.tensor(token_bytes, dtype=torch.int32, device='cpu')
token_bytes_path = os.path.join(tokenizer_dir, "token_bytes.pt")
with open(token_bytes_path, "wb") as f:
    torch.save(token_bytes, f)
print(f"Saved token_bytes to {token_bytes_path}")

# Log to report
from nanochat.report import get_report
token_bytes_nonzero = (token_bytes[token_bytes > 0]).to(dtype=torch.float32)
# get_report().log(section="Tokenizer training", data=[
#     # vars(args), # argparse command line arguments
#     {"train_time": train_time},
#     {"num_special_tokens": len(special_set)},
#     {
#         "token_bytes_min": int(token_bytes_nonzero.min().item()),
#         "token_bytes_max": int(token_bytes_nonzero.max().item()),
#         "token_bytes_mean": token_bytes_nonzero.mean().item(),
#         "token_bytes_std": token_bytes_nonzero.std().item(),
#     }
# ])
# Out:
# 2026-03-16 20:24:45,299 - rustbpe - INFO - Processing sequences from iterator (buffer_size: 8192)
# max_chars: 2,000,000,000
# doc_cap: 10,000
# vocab_size: 32,768
# 2026-03-16 20:26:51,753 - rustbpe - INFO - Processed 758523 sequences total, 2098273 unique
# 2026-03-16 20:26:51,974 - rustbpe - INFO - Starting BPE training: 32503 merges to compute
# 2026-03-16 20:26:51,975 - rustbpe - INFO - Computing initial pair counts from 2098273 unique sequences
# 2026-03-16 20:26:54,914 - rustbpe - INFO - Building heap with 19260 unique pairs
# 2026-03-16 20:26:54,918 - rustbpe - INFO - Starting merge loop
# 2026-03-16 20:26:59,326 - rustbpe - INFO - Progress: 1% (326/32503 merges) - Last merge: (277, 115) -> 581 (frequency: 613290)
# 2026-03-16 20:27:00,027 - rustbpe - INFO - Progress: 2% (651/32503 merges) - Last merge: (316, 291) -> 906 (frequency: 250642)
# 2026-03-16 20:27:00,477 - rustbpe - INFO - Progress: 3% (976/32503 merges) - Last merge: (119, 624) -> 1231 (frequency: 156115)
# 2026-03-16 20:27:00,804 - rustbpe - INFO - Progress: 4% (1301/32503 merges) - Last merge: (346, 280) -> 1556 (frequency: 110039)
# 2026-03-16 20:27:01,036 - rustbpe - INFO - Progress: 5% (1626/32503 merges) - Last merge: (300, 388) -> 1881 (frequency: 84284)
# 2026-03-16 20:27:01,244 - rustbpe - INFO - Progress: 6% (1951/32503 merges) - Last merge: (1144, 386) -> 2206 (frequency: 67727)
# 2026-03-16 20:27:01,421 - rustbpe - INFO - Progress: 7% (2276/32503 merges) - Last merge: (837, 2269) -> 2531 (frequency: 55610)
# 2026-03-16 20:27:01,567 - rustbpe - INFO - Progress: 8% (2601/32503 merges) - Last merge: (644, 600) -> 2856 (frequency: 47028)
# 2026-03-16 20:27:01,788 - rustbpe - INFO - Progress: 9% (2926/32503 merges) - Last merge: (98, 322) -> 3181 (frequency: 39894)
# 2026-03-16 20:27:01,949 - rustbpe - INFO - Progress: 10% (3251/32503 merges) - Last merge: (3041, 320) -> 3506 (frequency: 34126)
# 2026-03-16 20:27:02,093 - rustbpe - INFO - Progress: 11% (3576/32503 merges) - Last merge: (257, 384) -> 3831 (frequency: 30077)
# 2026-03-16 20:27:02,189 - rustbpe - INFO - Progress: 12% (3901/32503 merges) - Last merge: (1833, 735) -> 4156 (frequency: 26416)
# 2026-03-16 20:27:02,328 - rustbpe - INFO - Progress: 13% (4226/32503 merges) - Last merge: (968, 3473) -> 4481 (frequency: 23775)
# 2026-03-16 20:27:02,474 - rustbpe - INFO - Progress: 14% (4551/32503 merges) - Last merge: (289, 438) -> 4806 (frequency: 21338)
# 2026-03-16 20:27:02,558 - rustbpe - INFO - Progress: 15% (4876/32503 merges) - Last merge: (409, 2725) -> 5131 (frequency: 19344)
# 2026-03-16 20:27:02,655 - rustbpe - INFO - Progress: 16% (5201/32503 merges) - Last merge: (266, 3869) -> 5456 (frequency: 17654)
# 2026-03-16 20:27:02,740 - rustbpe - INFO - Progress: 17% (5526/32503 merges) - Last merge: (345, 1139) -> 5781 (frequency: 16294)
# 2026-03-16 20:27:02,817 - rustbpe - INFO - Progress: 18% (5851/32503 merges) - Last merge: (1397, 726) -> 6106 (frequency: 14993)
# 2026-03-16 20:27:02,876 - rustbpe - INFO - Progress: 19% (6176/32503 merges) - Last merge: (356, 115) -> 6431 (frequency: 13908)
# 2026-03-16 20:27:03,009 - rustbpe - INFO - Progress: 20% (6501/32503 merges) - Last merge: (3589, 358) -> 6756 (frequency: 12876)
# 2026-03-16 20:27:03,111 - rustbpe - INFO - Progress: 21% (6826/32503 merges) - Last merge: (1829, 116) -> 7081 (frequency: 11963)
# 2026-03-16 20:27:03,168 - rustbpe - INFO - Progress: 22% (7151/32503 merges) - Last merge: (3198, 388) -> 7406 (frequency: 11153)
# 2026-03-16 20:27:03,252 - rustbpe - INFO - Progress: 23% (7476/32503 merges) - Last merge: (83, 109) -> 7731 (frequency: 10513)
# 2026-03-16 20:27:03,327 - rustbpe - INFO - Progress: 24% (7801/32503 merges) - Last merge: (1523, 274) -> 8056 (frequency: 9859)
# 2026-03-16 20:27:03,384 - rustbpe - INFO - Progress: 25% (8126/32503 merges) - Last merge: (276, 779) -> 8381 (frequency: 9284)
# 2026-03-16 20:27:03,461 - rustbpe - INFO - Progress: 26% (8451/32503 merges) - Last merge: (264, 258) -> 8706 (frequency: 8800)
# 2026-03-16 20:27:03,525 - rustbpe - INFO - Progress: 27% (8776/32503 merges) - Last merge: (446, 485) -> 9031 (frequency: 8291)
# 2026-03-16 20:27:03,582 - rustbpe - INFO - Progress: 28% (9101/32503 merges) - Last merge: (311, 5303) -> 9356 (frequency: 7846)
# 2026-03-16 20:27:03,656 - rustbpe - INFO - Progress: 29% (9426/32503 merges) - Last merge: (3938, 5300) -> 9681 (frequency: 7442)
# 2026-03-16 20:27:03,711 - rustbpe - INFO - Progress: 30% (9751/32503 merges) - Last merge: (403, 378) -> 10006 (frequency: 7105)
# 2026-03-16 20:27:03,745 - rustbpe - INFO - Progress: 31% (10076/32503 merges) - Last merge: (1632, 432) -> 10331 (frequency: 6733)
# 2026-03-16 20:27:03,821 - rustbpe - INFO - Progress: 32% (10401/32503 merges) - Last merge: (463, 112) -> 10656 (frequency: 6411)
# 2026-03-16 20:27:03,875 - rustbpe - INFO - Progress: 33% (10726/32503 merges) - Last merge: (2885, 1642) -> 10981 (frequency: 6107)
# 2026-03-16 20:27:03,935 - rustbpe - INFO - Progress: 34% (11052/32503 merges) - Last merge: (7338, 659) -> 11307 (frequency: 5823)
# 2026-03-16 20:27:03,992 - rustbpe - INFO - Progress: 35% (11377/32503 merges) - Last merge: (366, 466) -> 11632 (frequency: 5557)
# 2026-03-16 20:27:04,044 - rustbpe - INFO - Progress: 36% (11702/32503 merges) - Last merge: (6414, 3329) -> 11957 (frequency: 5302)
# 2026-03-16 20:27:04,091 - rustbpe - INFO - Progress: 37% (12027/32503 merges) - Last merge: (317, 2969) -> 12282 (frequency: 5078)
# 2026-03-16 20:27:04,139 - rustbpe - INFO - Progress: 38% (12352/32503 merges) - Last merge: (329, 98) -> 12607 (frequency: 4876)
# 2026-03-16 20:27:04,179 - rustbpe - INFO - Progress: 39% (12677/32503 merges) - Last merge: (296, 2198) -> 12932 (frequency: 4667)
# 2026-03-16 20:27:04,274 - rustbpe - INFO - Progress: 40% (13002/32503 merges) - Last merge: (1033, 10279) -> 13257 (frequency: 4466)
# 2026-03-16 20:27:04,329 - rustbpe - INFO - Progress: 41% (13327/32503 merges) - Last merge: (6205, 481) -> 13582 (frequency: 4293)
# 2026-03-16 20:27:04,365 - rustbpe - INFO - Progress: 42% (13652/32503 merges) - Last merge: (6098, 280) -> 13907 (frequency: 4134)
# 2026-03-16 20:27:04,408 - rustbpe - INFO - Progress: 43% (13977/32503 merges) - Last merge: (404, 836) -> 14232 (frequency: 3983)
# 2026-03-16 20:27:04,451 - rustbpe - INFO - Progress: 44% (14302/32503 merges) - Last merge: (264, 3056) -> 14557 (frequency: 3831)
# 2026-03-16 20:27:04,507 - rustbpe - INFO - Progress: 45% (14627/32503 merges) - Last merge: (8335, 115) -> 14882 (frequency: 3688)
# 2026-03-16 20:27:04,572 - rustbpe - INFO - Progress: 46% (14952/32503 merges) - Last merge: (273, 5886) -> 15207 (frequency: 3557)
# 2026-03-16 20:27:04,603 - rustbpe - INFO - Progress: 47% (15277/32503 merges) - Last merge: (5397, 581) -> 15532 (frequency: 3427)
# 2026-03-16 20:27:04,636 - rustbpe - INFO - Progress: 48% (15602/32503 merges) - Last merge: (3539, 1400) -> 15857 (frequency: 3307)
# 2026-03-16 20:27:04,677 - rustbpe - INFO - Progress: 49% (15927/32503 merges) - Last merge: (954, 258) -> 16182 (frequency: 3191)
# 2026-03-16 20:27:04,716 - rustbpe - INFO - Progress: 50% (16252/32503 merges) - Last merge: (282, 1124) -> 16507 (frequency: 3088)
# 2026-03-16 20:27:04,750 - rustbpe - INFO - Progress: 51% (16577/32503 merges) - Last merge: (1790, 11915) -> 16832 (frequency: 2986)
# 2026-03-16 20:27:04,791 - rustbpe - INFO - Progress: 52% (16902/32503 merges) - Last merge: (3608, 3279) -> 17157 (frequency: 2894)
# 2026-03-16 20:27:04,827 - rustbpe - INFO - Progress: 53% (17227/32503 merges) - Last merge: (404, 8211) -> 17482 (frequency: 2807)
# 2026-03-16 20:27:04,872 - rustbpe - INFO - Progress: 54% (17552/32503 merges) - Last merge: (447, 8844) -> 17807 (frequency: 2732)
# 2026-03-16 20:27:04,904 - rustbpe - INFO - Progress: 55% (17877/32503 merges) - Last merge: (2016, 1223) -> 18132 (frequency: 2655)
# 2026-03-16 20:27:04,933 - rustbpe - INFO - Progress: 56% (18202/32503 merges) - Last merge: (461, 268) -> 18457 (frequency: 2573)
# 2026-03-16 20:27:04,958 - rustbpe - INFO - Progress: 57% (18527/32503 merges) - Last merge: (265, 274) -> 18782 (frequency: 2499)
# 2026-03-16 20:27:04,983 - rustbpe - INFO - Progress: 58% (18852/32503 merges) - Last merge: (431, 4264) -> 19107 (frequency: 2431)
# 2026-03-16 20:27:05,037 - rustbpe - INFO - Progress: 59% (19177/32503 merges) - Last merge: (860, 434) -> 19432 (frequency: 2363)
# 2026-03-16 20:27:05,064 - rustbpe - INFO - Progress: 60% (19502/32503 merges) - Last merge: (489, 1629) -> 19757 (frequency: 2293)
# 2026-03-16 20:27:05,102 - rustbpe - INFO - Progress: 61% (19827/32503 merges) - Last merge: (316, 111) -> 20082 (frequency: 2234)
# 2026-03-16 20:27:05,135 - rustbpe - INFO - Progress: 62% (20152/32503 merges) - Last merge: (373, 17797) -> 20407 (frequency: 2174)
# 2026-03-16 20:27:05,164 - rustbpe - INFO - Progress: 63% (20477/32503 merges) - Last merge: (6072, 1429) -> 20732 (frequency: 2121)
# 2026-03-16 20:27:05,204 - rustbpe - INFO - Progress: 64% (20802/32503 merges) - Last merge: (5829, 1269) -> 21057 (frequency: 2065)
# 2026-03-16 20:27:05,229 - rustbpe - INFO - Progress: 65% (21127/32503 merges) - Last merge: (3781, 4610) -> 21382 (frequency: 2011)
# 2026-03-16 20:27:05,263 - rustbpe - INFO - Progress: 66% (21452/32503 merges) - Last merge: (1520, 8522) -> 21707 (frequency: 1958)
# 2026-03-16 20:27:05,308 - rustbpe - INFO - Progress: 67% (21778/32503 merges) - Last merge: (468, 2578) -> 22033 (frequency: 1905)
# 2026-03-16 20:27:05,335 - rustbpe - INFO - Progress: 68% (22103/32503 merges) - Last merge: (738, 9526) -> 22358 (frequency: 1858)
# 2026-03-16 20:27:05,389 - rustbpe - INFO - Progress: 69% (22428/32503 merges) - Last merge: (12489, 6674) -> 22683 (frequency: 1813)
# 2026-03-16 20:27:05,416 - rustbpe - INFO - Progress: 70% (22753/32503 merges) - Last merge: (270, 12737) -> 23008 (frequency: 1768)
# 2026-03-16 20:27:05,437 - rustbpe - INFO - Progress: 71% (23078/32503 merges) - Last merge: (440, 6764) -> 23333 (frequency: 1724)
# 2026-03-16 20:27:05,466 - rustbpe - INFO - Progress: 72% (23403/32503 merges) - Last merge: (1942, 99) -> 23658 (frequency: 1683)
# 2026-03-16 20:27:05,493 - rustbpe - INFO - Progress: 73% (23728/32503 merges) - Last merge: (5931, 263) -> 23983 (frequency: 1645)
# 2026-03-16 20:27:05,513 - rustbpe - INFO - Progress: 74% (24053/32503 merges) - Last merge: (287, 508) -> 24308 (frequency: 1605)
# 2026-03-16 20:27:05,533 - rustbpe - INFO - Progress: 75% (24378/32503 merges) - Last merge: (2745, 833) -> 24633 (frequency: 1570)
# 2026-03-16 20:27:05,567 - rustbpe - INFO - Progress: 76% (24703/32503 merges) - Last merge: (319, 2622) -> 24958 (frequency: 1532)
# 2026-03-16 20:27:05,590 - rustbpe - INFO - Progress: 77% (25028/32503 merges) - Last merge: (5001, 14668) -> 25283 (frequency: 1498)
# 2026-03-16 20:27:05,614 - rustbpe - INFO - Progress: 78% (25353/32503 merges) - Last merge: (431, 6784) -> 25608 (frequency: 1464)
# 2026-03-16 20:27:05,636 - rustbpe - INFO - Progress: 79% (25678/32503 merges) - Last merge: (3395, 24564) -> 25933 (frequency: 1434)
# 2026-03-16 20:27:05,656 - rustbpe - INFO - Progress: 80% (26003/32503 merges) - Last merge: (6605, 70) -> 26258 (frequency: 1404)
# 2026-03-16 20:27:05,681 - rustbpe - INFO - Progress: 81% (26328/32503 merges) - Last merge: (87, 1206) -> 26583 (frequency: 1374)
# 2026-03-16 20:27:05,705 - rustbpe - INFO - Progress: 82% (26653/32503 merges) - Last merge: (2409, 350) -> 26908 (frequency: 1345)
# 2026-03-16 20:27:05,727 - rustbpe - INFO - Progress: 83% (26978/32503 merges) - Last merge: (1053, 471) -> 27233 (frequency: 1315)
# 2026-03-16 20:27:05,757 - rustbpe - INFO - Progress: 84% (27303/32503 merges) - Last merge: (1817, 263) -> 27558 (frequency: 1287)
# 2026-03-16 20:27:05,780 - rustbpe - INFO - Progress: 85% (27628/32503 merges) - Last merge: (18797, 810) -> 27883 (frequency: 1261)
# 2026-03-16 20:27:05,796 - rustbpe - INFO - Progress: 86% (27953/32503 merges) - Last merge: (3527, 6961) -> 28208 (frequency: 1235)
# 2026-03-16 20:27:05,835 - rustbpe - INFO - Progress: 87% (28278/32503 merges) - Last merge: (296, 335) -> 28533 (frequency: 1209)
# 2026-03-16 20:27:05,854 - rustbpe - INFO - Progress: 88% (28603/32503 merges) - Last merge: (121, 10596) -> 28858 (frequency: 1183)
# 2026-03-16 20:27:05,873 - rustbpe - INFO - Progress: 89% (28928/32503 merges) - Last merge: (20347, 1521) -> 29183 (frequency: 1157)
# 2026-03-16 20:27:05,890 - rustbpe - INFO - Progress: 90% (29253/32503 merges) - Last merge: (899, 4515) -> 29508 (frequency: 1133)
# 2026-03-16 20:27:05,913 - rustbpe - INFO - Progress: 91% (29578/32503 merges) - Last merge: (16090, 97) -> 29833 (frequency: 1114)
# 2026-03-16 20:27:05,928 - rustbpe - INFO - Progress: 92% (29903/32503 merges) - Last merge: (6697, 277) -> 30158 (frequency: 1092)
# 2026-03-16 20:27:05,945 - rustbpe - INFO - Progress: 93% (30228/32503 merges) - Last merge: (23443, 4199) -> 30483 (frequency: 1073)
# 2026-03-16 20:27:05,967 - rustbpe - INFO - Progress: 94% (30553/32503 merges) - Last merge: (6650, 2154) -> 30808 (frequency: 1052)
# 2026-03-16 20:27:05,996 - rustbpe - INFO - Progress: 95% (30878/32503 merges) - Last merge: (1689, 111) -> 31133 (frequency: 1031)
# 2026-03-16 20:27:06,010 - rustbpe - INFO - Progress: 96% (31203/32503 merges) - Last merge: (1666, 284) -> 31458 (frequency: 1011)
# 2026-03-16 20:27:06,027 - rustbpe - INFO - Progress: 97% (31528/32503 merges) - Last merge: (807, 1568) -> 31783 (frequency: 992)
# 2026-03-16 20:27:06,053 - rustbpe - INFO - Progress: 98% (31853/32503 merges) - Last merge: (348, 5350) -> 32108 (frequency: 976)
# 2026-03-16 20:27:06,067 - rustbpe - INFO - Progress: 99% (32178/32503 merges) - Last merge: (725, 29355) -> 32433 (frequency: 959)
# 2026-03-16 20:27:06,081 - rustbpe - INFO - Progress: 100% (32503/32503 merges) - Last merge: (3896, 542) -> 32758 (frequency: 942)
# 2026-03-16 20:27:06,082 - rustbpe - INFO - Finished training: 32503 merges completed
# Training time: 142.04s
# Saved tokenizer encoding to /root/.cache/nanochat/tokenizer/tokenizer.pkl
# Saved token_bytes to /root/.cache/nanochat/tokenizer/token_bytes.pt

# %%
# !python -m scripts.base_train \
#     --parallel dp \
#     --run nb-base-train \
#     --checkpoints-dir /kaggle/working/base_checkpoints \
#     --device-type cuda \
#     --fp8 \
#     --fp8-recipe tensorwise \
#     --depth 20 \
#     --aspect-ratio 64 \
#     --head-dim 128 \
#     --max-seq-len 2048 \
#     --window-pattern SSSL \
#     --num-iterations 50 \
#     --target-flops -1.0 \
#     --target-param-data-ratio 10.5 \
#     --device-batch-size 8 \
#     --total-batch-size 524288 \
#     --embedding-lr 0.3 \
#     --unembedding-lr 0.004 \
#     --weight-decay 0.2 \
#     --matrix-lr 0.02 \
#     --scalar-lr 0.5 \
#     --adam-beta1 0.8 \
#     --adam-beta2 0.95 \
#     --warmup-ratio 0.0 \
#     --warmdown-ratio 0.5 \
#     --final-lr-frac 0.0 \
#     --resume-from-step -1 \
#     --eval-every 20 \
#     --eval-tokens 1048576 \
#     --core-metric-every 20 \
#     --core-metric-max-per-task 500 \
#     --sample-every 500 \
#     --save-every 500 \
#     --model-tag nb_d20

# %%
# %env NANOCHAT_PARALLEL=ddp

# %%
import runpy, sys
old_argv = sys.argv[:]
sys.argv = train_argv
try:
    runpy.run_module('scripts.base_train', run_name='__main__')
finally:
    sys.argv = old_argv

# %%
# train_argv

# %%
TRAINING_CONFIG['model_tag'] = 'nb_d20_research_moe16_lr005'
TRAINING_CONFIG['checkpoints_dir'] =  "research_checkpoints"
train_argv = base_train_argv(TRAINING_CONFIG)
print(' '.join(train_argv[:14]), '...')
# Out:
# scripts.base_train --run nb-base-train --device-type  --checkpoints-dir research_checkpoints --depth 8 --aspect-ratio 64 --head-dim 16 --max-seq-len ...

# %%
# train_argv

# %% [markdown]
# ## 4) Optional: run standalone base_eval.py after training
# Use this when you want a full explicit eval pass after training completes.

# %%
BASE_EVAL_CONFIG = {
    'device_type': TRAINING_CONFIG['device_type'],
    'model_tag': TRAINING_CONFIG['model_tag'],
    'step': None,  # None = latest checkpoint
    'eval': 'core,bpb,sample',
    'max_per_task': 500,
    'device_batch_size': 16,
    'split_tokens': 8 * 524288,
}

def base_eval_argv(cfg: dict) -> list[str]:
    flag_map = {
        'device_type': '--device-type',
        'model_tag': '--model-tag',
        'step': '--step',
        'eval': '--eval',
        'max_per_task': '--max-per-task',
        'device_batch_size': '--device-batch-size',
        'split_tokens': '--split-tokens',
    }
    argv = ['scripts.base_eval']
    for k, flag in flag_map.items():
        if k not in cfg or cfg[k] is None:
            continue
        argv.extend([flag, str(cfg[k])])
    return argv

eval_argv = base_eval_argv(BASE_EVAL_CONFIG)
print(' '.join(eval_argv))
# Out:
# scripts.base_eval --device-type  --model-tag nb_d20_research_moe16_lr005 --eval core,bpb,sample --max-per-task 500 --device-batch-size 16 --split-tokens 4194304

# %%
# Uncomment to run explicit post-training eval:
# import runpy, sys
# old_argv = sys.argv[:]
# sys.argv = eval_argv
# try:
#     runpy.run_module('scripts.base_eval', run_name='__main__')
# finally:
#     sys.argv = old_argv

# %% [markdown]
# ## Notes
# - If you set `core_metric_every=-1`, training will skip CORE eval (this was the main reason it can appear missing).
# - For quick smoke tests, lower depth/sequence/batch/token budget dramatically.
# - Multi-GPU distributed runs are still best launched from terminal with `torchrun`.

# %% [markdown]
# ## 5) Research branch config (MoE / Permutation / RemixedLinear)
#
# Use this when you want notebook-driven experiments aligned with the `contextlinear.ipynb` branches.

# %%
# import os
# os.environ["NANOCHAT_BASE_DIR"] = "/kaggle/working/base_checkpoints/research_model"

TRAINING_CONFIG['model_tag'] = 'nb_d20_research_moe16_lr005'
TRAINING_CONFIG['checkpoints_dir'] = "/kaggle/working/research_remix_linear/checkpoints"

# %%
RESEARCH_ALLOWED_KEYS = {
    "use_moe", "num_experts", "moe_num_experts","total_embed_dim", "router_dim", "capacity_factor",
    "use_sparse_top_k", "top_k", "routing_mode", "context_window",
    "causal", "use_expert_mlp", "use_output_projection",
    "use_expert_bias", "dropout", "use_shared_base", "shared_base_dim",
    "use_vocab_prior", "expert_residual", "allow_replacement",
    "use_embed_refine", "target_dim", "selection_mode", "use_perm",
    "use_remixed_linear", "context_dim", "linear_basis_size", "remixed_linear_kwargs",
    "router_context_window", "router_causal", "router_num_heads", "router_num_queries",
    "router_n_layers", "router_use_vocab_prior",
    "use_pos_embed", "moe_use_abs_pos_embed","research_embedding_lr"
}

RESEARCH_MODEL_CONFIG = {
    "use_moe": False,
    "use_perm": False,
    "num_experts": 8,
    # "moe_num_experts": 16,
    "router_dim": 64,
    "target_dim": 64,
    "selection_mode": "soft",
    "allow_replacement": True,
    "use_remixed_linear": True,
    # "use_remix_linear": True,
    "context_dim": 64,
    # "research_embedding_lr": 0.05,
    # "research_unembedding_lr": 0.05,
    # "research_matrix_lr": 0.05,
    # "research_scaler_lr" : 0.05,
    # 'research_adam_beta1': 0.8,
    # 'research_adam_beta2': 0.99,
    # "research_one_cycle": True,
    # "research_warmup": 0.3,
    "moe_use_abs_pos_embed": True,
    "linear_basis_size": 64,
    "router_context_window": -1,
    "router_causal": True,
    "router_num_heads": 4,
    "router_num_queries": 8,
    "router_n_layers": 2,
    "router_use_vocab_prior": False,
    "use_pos_embed": False,
    "moe_use_abs_pos_embed": True,
    "remixed_linear_kwargs": {
        "use_basis_gate": True,
        "use_output_gate": True,
        "use_context": True,
    },
}


def research_to_gpt_kwargs(cfg: dict) -> dict:
    unexpected = sorted(set(cfg) - RESEARCH_ALLOWED_KEYS)
    if unexpected:
        print(f"Warning: unexpected research keys: {unexpected}")
    return {
        "use_moe": cfg.get("use_moe", False),
        "use_perm": cfg.get("use_perm", False),
        "num_experts": cfg.get("num_experts", 8),
        # "moe_num_experts": cfg.get("moe_num_experts", 8),  # <-- add this
        "router_dim": cfg.get("router_dim", 64),
        "target_dim": cfg.get("target_dim", 64),
        "selection_mode": cfg.get("selection_mode", "soft"),
        "allow_replacement": cfg.get("allow_replacement", True),
        "use_remixed_linear": cfg.get("use_remixed_linear", False),
        "context_dim": cfg.get("context_dim", 64),
        "linear_basis_size": cfg.get("linear_basis_size", 64),
        "router_context_window": cfg.get("router_context_window", -1),
        "router_causal": cfg.get("router_causal", True),
        "router_num_heads": cfg.get("router_num_heads", 4),
        "router_num_queries": cfg.get("router_num_queries", 8),
        "router_n_layers": cfg.get("router_n_layers", 2),
        "router_use_vocab_prior": cfg.get("router_use_vocab_prior", False),
        "use_pos_embed": cfg.get("use_pos_embed", False),
        "moe_use_abs_pos_embed": cfg.get("moe_use_abs_pos_embed", True),
        "remixed_linear_kwargs": cfg.get("remixed_linear_kwargs", {
            "use_basis_gate": True,
            "use_output_gate": True,
            "use_context": True,
        }),
    }

RESEARCH_GPT_KWARGS = research_to_gpt_kwargs(RESEARCH_MODEL_CONFIG)
RESEARCH_GPT_KWARGS
# Out:
# {'use_moe': False,
#  'use_perm': False,
#  'num_experts': 8,
#  'router_dim': 64,
#  'target_dim': 64,
#  'selection_mode': 'soft',
#  'allow_replacement': True,
#  'use_remixed_linear': True,
#  'context_dim': 64,
#  'linear_basis_size': 64,
#  'router_context_window': -1,
#  'router_causal': True,
#  'router_num_heads': 4,
#  'router_num_queries': 8,
#  'router_n_layers': 2,
#  'router_use_vocab_prior': False,
#  'use_pos_embed': False,
#  'moe_use_abs_pos_embed': True,
#  'remixed_linear_kwargs': {'use_basis_gate': True,
#   'use_output_gate': True,
#   'use_context': True}}

# %%
MOE_SCALE = 5.0  # applied when any research mode is active


def _resolve_research_lrs(training_cfg: dict, research_kwargs: dict, moe_scale: float) -> dict:
    # Apply MOE scale to all LR groups whenever any research branch is enabled.
    research_active = bool(
        research_kwargs.get("use_moe", False)
        or research_kwargs.get("use_perm", False)
        or research_kwargs.get("use_remixed_linear", False)
    )
    scale = float(moe_scale) if research_active else 1.0

    resolved = {
        "embedding_lr": float(training_cfg["embedding_lr"]) * scale,
        "unembedding_lr": float(training_cfg["unembedding_lr"]) * scale,
        "matrix_lr": float(training_cfg["matrix_lr"]) * scale,
        "scalar_lr": float(training_cfg["scalar_lr"]) * scale,
    }

    # Research-specific LR overrides take precedence over both base LR and MOE_SCALE.
    # Note: `research_scaler_lr` is the canonical key for scalar LR overrides.
    override_map = {
        "embedding_lr": ["research_embedding_lr"],
        "unembedding_lr": ["research_unembedding_lr"],
        "matrix_lr": ["research_matrix_lr"],
        "scalar_lr": ["research_scaler_lr", "research_scalar_lr"],  # support legacy alias too
    }
    for target_key, candidates in override_map.items():
        override_val = next((research_kwargs[k] for k in candidates if research_kwargs.get(k, None) is not None), None)
        if override_val is not None:
            resolved[target_key] = float(override_val)
    return resolved


def _resolve_schedule(training_cfg: dict, research_kwargs: dict) -> tuple[float, float, float]:
    warmup = float(research_kwargs.get("research_warmup", training_cfg.get("warmup_ratio", 0.0)))
    one_cycle = bool(research_kwargs.get("research_one_cycle", False))
    if one_cycle:
        warmdown = max(0.0, 1.0 - warmup)
        final_lr_frac = 0.0
    else:
        warmdown = float(training_cfg.get("warmdown_ratio", 0.5))
        final_lr_frac = float(training_cfg.get("final_lr_frac", 0.0))
    return warmup, warmdown, final_lr_frac


def research_train_argv(training_cfg: dict, research_kwargs: dict, moe_scale: float = MOE_SCALE) -> list[str]:
    argv = base_train_argv(training_cfg)

    # bool flags
    if research_kwargs.get("use_moe", False):
        argv += ["--use-moe"]
    if research_kwargs.get("use_perm", False):
        argv += ["--use-perm"]
    if research_kwargs.get("allow_replacement", False):
        argv += ["--allow-replacement"]
    if research_kwargs.get("use_remixed_linear", False):
        argv += ["--use-remixed-linear"]

    # scalar args
    scalar_map = {
        "num_experts": "--num-experts",
        "router_dim": "--router-dim",
        "target_dim": "--target-dim",
        "selection_mode": "--selection-mode",
        "context_dim": "--context-dim",
        "linear_basis_size": "--linear-basis-size",
    }
    for k, flag in scalar_map.items():
        if k in research_kwargs and research_kwargs[k] is not None:
            argv += [flag, str(research_kwargs[k])]

    # remixed linear gate controls
    remix_kwargs = research_kwargs.get("remixed_linear_kwargs", {})
    argv += ["--remix-use-basis-gate", str(int(bool(remix_kwargs.get("use_basis_gate", True))))]
    argv += ["--remix-use-output-gate", str(int(bool(remix_kwargs.get("use_output_gate", True))))]
    argv += ["--remix-use-context", str(int(bool(remix_kwargs.get("use_context", True))))]

    resolved_lrs = _resolve_research_lrs(training_cfg, research_kwargs, moe_scale)
    argv += ["--embedding-lr", str(resolved_lrs["embedding_lr"])]
    argv += ["--unembedding-lr", str(resolved_lrs["unembedding_lr"])]
    argv += ["--matrix-lr", str(resolved_lrs["matrix_lr"])]
    argv += ["--scalar-lr", str(resolved_lrs["scalar_lr"])]

    # Research-specific beta overrides (if provided)
    beta1 = float(research_kwargs.get("research_adam_beta1", training_cfg.get("adam_beta1", 0.8)))
    beta2 = float(research_kwargs.get("research_adam_beta2", training_cfg.get("adam_beta2", 0.95)))
    argv += ["--adam-beta1", str(beta1), "--adam-beta2", str(beta2)]

    warmup, warmdown, final_lr_frac = _resolve_schedule(training_cfg, research_kwargs)
    argv += [
        "--warmup-ratio", str(warmup),
        "--warmdown-ratio", str(warmdown),
        "--final-lr-frac", str(final_lr_frac),
    ]

    if bool(research_kwargs.get("research_use_pos_embed", research_kwargs.get("use_pos_embed", False))):
        argv += ["--use-pos-embed"]
    argv += ["--moe-use-abs-pos-embed", str(int(bool(research_kwargs.get("moe_use_abs_pos_embed", True))))]

    return argv


# For research sweeps keep sequence length and target dim fixed for comparability.
TRAINING_CONFIG['max_seq_len'] = 64
RESEARCH_GPT_KWARGS['target_dim'] = 64
# Ensure attention divisibility with target_dim=64
TRAINING_CONFIG['head_dim'] = 16


RESEARCH_RUN_KWARGS = {
    **RESEARCH_GPT_KWARGS,  # model keys
    "research_embedding_lr": 0.05,
    "research_unembedding_lr": 0.05,
    "research_matrix_lr": 0.05,
    "research_scaler_lr": 0.05,
    "research_adam_beta1": 0.8,
    "research_adam_beta2": 0.99,
    "research_one_cycle": True,
    "research_warmup": 0.3,
    # "moe_num_experts": 16,

}
research_argv = research_train_argv(TRAINING_CONFIG, RESEARCH_RUN_KWARGS, moe_scale=MOE_SCALE)


# research_argv = research_train_argv(TRAINING_CONFIG, RESEARCH_GPT_KWARGS, moe_scale=MOE_SCALE)
print(' '.join(research_argv))
# Out:
# scripts.base_train --run nb-base-train --device-type  --checkpoints-dir /kaggle/working/research/checkpoints --depth 8 --aspect-ratio 64 --head-dim 16 --max-seq-len 64 --window-pattern SSSL --num-iterations 50 --device-batch-size 8 --total-batch-size 8192 --embedding-lr 0.3 --unembedding-lr 0.004 --weight-decay 0.2 --matrix-lr 0.02 --scalar-lr 0.5 --adam-beta1 0.8 --adam-beta2 0.95 --warmup-ratio 0.0 --warmdown-ratio 0.5 --final-lr-frac 0.0 --resume-from-step -1 --eval-every 1000 --eval-tokens 1048576 --core-metric-every -1 --core-metric-max-per-task 500 --sample-every 500 --save-every 500 --model-tag nb_d20_research_moe16_lr005 --fp8-recipe tensorwise --allow-replacement --use-remixed-linear --num-experts 8 --router-dim 64 --target-dim 64 --selection-mode soft --context-dim 64 --linear-basis-size 64 --remix-use-basis-gate 1 --remix-use-output-gate 1 --remix-use-context 1 --embedding-lr 0.05 --unembedding-lr 0.05 --matrix-lr 0.05 --scalar-lr 0.05 --adam-beta1 0.8 --adam-beta2 0.99 --warmup-ratio 0.3 --warmdown-ratio 0.7 --final-lr-frac 0.0 --moe-use-abs-pos-embed 1

# %%
# Run research training from notebook:
import runpy, sys
old_argv = sys.argv[:]
sys.argv = research_argv
try:
    runpy.run_module('scripts.base_train', run_name='__main__')
finally:
    sys.argv = old_argv

# %%
TRAINING_CONFIG['model_tag'] = 'nb_d20_research_moe17_lr005'
TRAINING_CONFIG['checkpoints_dir'] =  "research_moe_no_perm_checkpoints"
train_argv = base_train_argv(TRAINING_CONFIG)
print(' '.join(train_argv[:14]), '...')



RESEARCH_ALLOWED_KEYS = {
    "use_moe", "num_experts", "moe_num_experts","total_embed_dim", "router_dim", "capacity_factor",
    "use_sparse_top_k", "top_k", "routing_mode", "context_window",
    "causal", "use_expert_mlp", "use_output_projection",
    "use_expert_bias", "dropout", "use_shared_base", "shared_base_dim",
    "use_vocab_prior", "expert_residual", "allow_replacement",
    "use_embed_refine", "target_dim", "selection_mode", "use_perm",
    "use_remixed_linear", "context_dim", "linear_basis_size", "remixed_linear_kwargs",
    "router_context_window", "router_causal", "router_num_heads", "router_num_queries",
    "router_n_layers", "router_use_vocab_prior",
    "use_pos_embed", "moe_use_abs_pos_embed","research_embedding_lr"
}

RESEARCH_MODEL_CONFIG = {
    "use_moe": True,
    "use_perm": False,
    "num_experts": 8,
    # "moe_num_experts": 16,
    "router_dim": 64,
    "target_dim": 64,
    "selection_mode": "soft",
    "allow_replacement": True,
    "use_remixed_linear": False,
    # "use_remix_linear": True,
    "context_dim": 64,
    # "research_embedding_lr": 0.05,
    # "research_unembedding_lr": 0.05,
    # "research_matrix_lr": 0.05,
    # "research_scaler_lr" : 0.05,
    # 'research_adam_beta1': 0.8,
    # 'research_adam_beta2': 0.99,
    # "research_one_cycle": True,
    # "research_warmup": 0.3,
    "moe_use_abs_pos_embed": True,
    "linear_basis_size": 64,
    "router_context_window": -1,
    "router_causal": True,
    "router_num_heads": 4,
    "router_num_queries": 8,
    "router_n_layers": 2,
    "router_use_vocab_prior": False,
    "use_pos_embed": False,
    "moe_use_abs_pos_embed": True,
    "remixed_linear_kwargs": {
        "use_basis_gate": True,
        "use_output_gate": True,
        "use_context": True,
    },
}


def research_to_gpt_kwargs(cfg: dict) -> dict:
    unexpected = sorted(set(cfg) - RESEARCH_ALLOWED_KEYS)
    if unexpected:
        print(f"Warning: unexpected research keys: {unexpected}")
    return {
        "use_moe": cfg.get("use_moe", False),
        "use_perm": cfg.get("use_perm", False),
        "num_experts": cfg.get("num_experts", 8),
        # "moe_num_experts": cfg.get("moe_num_experts", 8),  # <-- add this
        "router_dim": cfg.get("router_dim", 64),
        "target_dim": cfg.get("target_dim", 64),
        "selection_mode": cfg.get("selection_mode", "soft"),
        "allow_replacement": cfg.get("allow_replacement", True),
        "use_remixed_linear": cfg.get("use_remixed_linear", False),
        "context_dim": cfg.get("context_dim", 64),
        "linear_basis_size": cfg.get("linear_basis_size", 64),
        "router_context_window": cfg.get("router_context_window", -1),
        "router_causal": cfg.get("router_causal", True),
        "router_num_heads": cfg.get("router_num_heads", 4),
        "router_num_queries": cfg.get("router_num_queries", 8),
        "router_n_layers": cfg.get("router_n_layers", 2),
        "router_use_vocab_prior": cfg.get("router_use_vocab_prior", False),
        "use_pos_embed": cfg.get("use_pos_embed", False),
        "moe_use_abs_pos_embed": cfg.get("moe_use_abs_pos_embed", True),
        "remixed_linear_kwargs": cfg.get("remixed_linear_kwargs", {
            "use_basis_gate": True,
            "use_output_gate": True,
            "use_context": True,
        }),
    }

RESEARCH_GPT_KWARGS = research_to_gpt_kwargs(RESEARCH_MODEL_CONFIG)
RESEARCH_GPT_KWARGS



MOE_SCALE = 5.0  # applied when any research mode is active


def _resolve_research_lrs(training_cfg: dict, research_kwargs: dict, moe_scale: float) -> dict:
    # Apply MOE scale to all LR groups whenever any research branch is enabled.
    research_active = bool(
        research_kwargs.get("use_moe", False)
        or research_kwargs.get("use_perm", False)
        or research_kwargs.get("use_remixed_linear", False)
    )
    scale = float(moe_scale) if research_active else 1.0

    resolved = {
        "embedding_lr": float(training_cfg["embedding_lr"]) * scale,
        "unembedding_lr": float(training_cfg["unembedding_lr"]) * scale,
        "matrix_lr": float(training_cfg["matrix_lr"]) * scale,
        "scalar_lr": float(training_cfg["scalar_lr"]) * scale,
    }

    # Research-specific LR overrides take precedence over both base LR and MOE_SCALE.
    # Note: `research_scaler_lr` is the canonical key for scalar LR overrides.
    override_map = {
        "embedding_lr": ["research_embedding_lr"],
        "unembedding_lr": ["research_unembedding_lr"],
        "matrix_lr": ["research_matrix_lr"],
        "scalar_lr": ["research_scaler_lr", "research_scalar_lr"],  # support legacy alias too
    }
    for target_key, candidates in override_map.items():
        override_val = next((research_kwargs[k] for k in candidates if research_kwargs.get(k, None) is not None), None)
        if override_val is not None:
            resolved[target_key] = float(override_val)
    return resolved


def _resolve_schedule(training_cfg: dict, research_kwargs: dict) -> tuple[float, float, float]:
    warmup = float(research_kwargs.get("research_warmup", training_cfg.get("warmup_ratio", 0.0)))
    one_cycle = bool(research_kwargs.get("research_one_cycle", False))
    if one_cycle:
        warmdown = max(0.0, 1.0 - warmup)
        final_lr_frac = 0.0
    else:
        warmdown = float(training_cfg.get("warmdown_ratio", 0.5))
        final_lr_frac = float(training_cfg.get("final_lr_frac", 0.0))
    return warmup, warmdown, final_lr_frac


def research_train_argv(training_cfg: dict, research_kwargs: dict, moe_scale: float = MOE_SCALE) -> list[str]:
    argv = base_train_argv(training_cfg)

    # bool flags
    if research_kwargs.get("use_moe", False):
        argv += ["--use-moe"]
    if research_kwargs.get("use_perm", False):
        argv += ["--use-perm"]
    if research_kwargs.get("allow_replacement", False):
        argv += ["--allow-replacement"]
    if research_kwargs.get("use_remixed_linear", False):
        argv += ["--use-remixed-linear"]

    # scalar args
    scalar_map = {
        "num_experts": "--num-experts",
        "router_dim": "--router-dim",
        "target_dim": "--target-dim",
        "selection_mode": "--selection-mode",
        "context_dim": "--context-dim",
        "linear_basis_size": "--linear-basis-size",
    }
    for k, flag in scalar_map.items():
        if k in research_kwargs and research_kwargs[k] is not None:
            argv += [flag, str(research_kwargs[k])]

    # remixed linear gate controls
    remix_kwargs = research_kwargs.get("remixed_linear_kwargs", {})
    argv += ["--remix-use-basis-gate", str(int(bool(remix_kwargs.get("use_basis_gate", True))))]
    argv += ["--remix-use-output-gate", str(int(bool(remix_kwargs.get("use_output_gate", True))))]
    argv += ["--remix-use-context", str(int(bool(remix_kwargs.get("use_context", True))))]

    resolved_lrs = _resolve_research_lrs(training_cfg, research_kwargs, moe_scale)
    argv += ["--embedding-lr", str(resolved_lrs["embedding_lr"])]
    argv += ["--unembedding-lr", str(resolved_lrs["unembedding_lr"])]
    argv += ["--matrix-lr", str(resolved_lrs["matrix_lr"])]
    argv += ["--scalar-lr", str(resolved_lrs["scalar_lr"])]

    # Research-specific beta overrides (if provided)
    beta1 = float(research_kwargs.get("research_adam_beta1", training_cfg.get("adam_beta1", 0.8)))
    beta2 = float(research_kwargs.get("research_adam_beta2", training_cfg.get("adam_beta2", 0.95)))
    argv += ["--adam-beta1", str(beta1), "--adam-beta2", str(beta2)]

    warmup, warmdown, final_lr_frac = _resolve_schedule(training_cfg, research_kwargs)
    argv += [
        "--warmup-ratio", str(warmup),
        "--warmdown-ratio", str(warmdown),
        "--final-lr-frac", str(final_lr_frac),
    ]

    if bool(research_kwargs.get("research_use_pos_embed", research_kwargs.get("use_pos_embed", False))):
        argv += ["--use-pos-embed"]
    argv += ["--moe-use-abs-pos-embed", str(int(bool(research_kwargs.get("moe_use_abs_pos_embed", True))))]

    return argv


# For research sweeps keep sequence length and target dim fixed for comparability.
TRAINING_CONFIG['max_seq_len'] = 64
RESEARCH_GPT_KWARGS['target_dim'] = 64
# Ensure attention divisibility with target_dim=64
TRAINING_CONFIG['head_dim'] = 16


RESEARCH_RUN_KWARGS = {
    **RESEARCH_GPT_KWARGS,  # model keys
    "research_embedding_lr": 0.05,
    "research_unembedding_lr": 0.05,
    "research_matrix_lr": 0.05,
    "research_scaler_lr": 0.05,
    "research_adam_beta1": 0.8,
    "research_adam_beta2": 0.99,
    "research_one_cycle": True,
    "research_warmup": 0.3,
    # "moe_num_experts": 16,

}
research_argv = research_train_argv(TRAINING_CONFIG, RESEARCH_RUN_KWARGS, moe_scale=MOE_SCALE)


# research_argv = research_train_argv(TRAINING_CONFIG, RESEARCH_GPT_KWARGS, moe_scale=MOE_SCALE)
print(' '.join(research_argv))

# %%
# Run research training from notebook:
import runpy, sys
old_argv = sys.argv[:]
sys.argv = research_argv
try:
    runpy.run_module('scripts.base_train', run_name='__main__')
finally:
    sys.argv = old_argv

# %%
TRAINING_CONFIG['model_tag'] = 'nb_d20_research_moe18_lr005'
TRAINING_CONFIG['checkpoints_dir'] =  "research_moe_perm_checkpoints"
train_argv = base_train_argv(TRAINING_CONFIG)
print(' '.join(train_argv[:14]), '...')



RESEARCH_ALLOWED_KEYS = {
    "use_moe", "num_experts", "moe_num_experts","total_embed_dim", "router_dim", "capacity_factor",
    "use_sparse_top_k", "top_k", "routing_mode", "context_window",
    "causal", "use_expert_mlp", "use_output_projection",
    "use_expert_bias", "dropout", "use_shared_base", "shared_base_dim",
    "use_vocab_prior", "expert_residual", "allow_replacement",
    "use_embed_refine", "target_dim", "selection_mode", "use_perm",
    "use_remixed_linear", "context_dim", "linear_basis_size", "remixed_linear_kwargs",
    "router_context_window", "router_causal", "router_num_heads", "router_num_queries",
    "router_n_layers", "router_use_vocab_prior",
    "use_pos_embed", "moe_use_abs_pos_embed","research_embedding_lr"
}

RESEARCH_MODEL_CONFIG = {
    "use_moe": True,
    "use_perm": True,
    "num_experts": 8,
    # "moe_num_experts": 16,
    "router_dim": 64,
    "target_dim": 64,
    "selection_mode": "soft",
    "allow_replacement": True,
    "use_remixed_linear": False,
    # "use_remix_linear": True,
    "context_dim": 64,
    # "research_embedding_lr": 0.05,
    # "research_unembedding_lr": 0.05,
    # "research_matrix_lr": 0.05,
    # "research_scaler_lr" : 0.05,
    # 'research_adam_beta1': 0.8,
    # 'research_adam_beta2': 0.99,
    # "research_one_cycle": True,
    # "research_warmup": 0.3,
    "moe_use_abs_pos_embed": True,
    "linear_basis_size": 64,
    "router_context_window": -1,
    "router_causal": True,
    "router_num_heads": 4,
    "router_num_queries": 8,
    "router_n_layers": 2,
    "router_use_vocab_prior": False,
    "use_pos_embed": False,
    "moe_use_abs_pos_embed": True,
    "remixed_linear_kwargs": {
        "use_basis_gate": True,
        "use_output_gate": True,
        "use_context": True,
    },
}


def research_to_gpt_kwargs(cfg: dict) -> dict:
    unexpected = sorted(set(cfg) - RESEARCH_ALLOWED_KEYS)
    if unexpected:
        print(f"Warning: unexpected research keys: {unexpected}")
    return {
        "use_moe": cfg.get("use_moe", False),
        "use_perm": cfg.get("use_perm", False),
        "num_experts": cfg.get("num_experts", 8),
        # "moe_num_experts": cfg.get("moe_num_experts", 8),  # <-- add this
        "router_dim": cfg.get("router_dim", 64),
        "target_dim": cfg.get("target_dim", 64),
        "selection_mode": cfg.get("selection_mode", "soft"),
        "allow_replacement": cfg.get("allow_replacement", True),
        "use_remixed_linear": cfg.get("use_remixed_linear", False),
        "context_dim": cfg.get("context_dim", 64),
        "linear_basis_size": cfg.get("linear_basis_size", 64),
        "router_context_window": cfg.get("router_context_window", -1),
        "router_causal": cfg.get("router_causal", True),
        "router_num_heads": cfg.get("router_num_heads", 4),
        "router_num_queries": cfg.get("router_num_queries", 8),
        "router_n_layers": cfg.get("router_n_layers", 2),
        "router_use_vocab_prior": cfg.get("router_use_vocab_prior", False),
        "use_pos_embed": cfg.get("use_pos_embed", False),
        "moe_use_abs_pos_embed": cfg.get("moe_use_abs_pos_embed", True),
        "remixed_linear_kwargs": cfg.get("remixed_linear_kwargs", {
            "use_basis_gate": True,
            "use_output_gate": True,
            "use_context": True,
        }),
    }

RESEARCH_GPT_KWARGS = research_to_gpt_kwargs(RESEARCH_MODEL_CONFIG)
RESEARCH_GPT_KWARGS



MOE_SCALE = 5.0  # applied when any research mode is active


def _resolve_research_lrs(training_cfg: dict, research_kwargs: dict, moe_scale: float) -> dict:
    # Apply MOE scale to all LR groups whenever any research branch is enabled.
    research_active = bool(
        research_kwargs.get("use_moe", False)
        or research_kwargs.get("use_perm", False)
        or research_kwargs.get("use_remixed_linear", False)
    )
    scale = float(moe_scale) if research_active else 1.0

    resolved = {
        "embedding_lr": float(training_cfg["embedding_lr"]) * scale,
        "unembedding_lr": float(training_cfg["unembedding_lr"]) * scale,
        "matrix_lr": float(training_cfg["matrix_lr"]) * scale,
        "scalar_lr": float(training_cfg["scalar_lr"]) * scale,
    }

    # Research-specific LR overrides take precedence over both base LR and MOE_SCALE.
    # Note: `research_scaler_lr` is the canonical key for scalar LR overrides.
    override_map = {
        "embedding_lr": ["research_embedding_lr"],
        "unembedding_lr": ["research_unembedding_lr"],
        "matrix_lr": ["research_matrix_lr"],
        "scalar_lr": ["research_scaler_lr", "research_scalar_lr"],  # support legacy alias too
    }
    for target_key, candidates in override_map.items():
        override_val = next((research_kwargs[k] for k in candidates if research_kwargs.get(k, None) is not None), None)
        if override_val is not None:
            resolved[target_key] = float(override_val)
    return resolved


def _resolve_schedule(training_cfg: dict, research_kwargs: dict) -> tuple[float, float, float]:
    warmup = float(research_kwargs.get("research_warmup", training_cfg.get("warmup_ratio", 0.0)))
    one_cycle = bool(research_kwargs.get("research_one_cycle", False))
    if one_cycle:
        warmdown = max(0.0, 1.0 - warmup)
        final_lr_frac = 0.0
    else:
        warmdown = float(training_cfg.get("warmdown_ratio", 0.5))
        final_lr_frac = float(training_cfg.get("final_lr_frac", 0.0))
    return warmup, warmdown, final_lr_frac


def research_train_argv(training_cfg: dict, research_kwargs: dict, moe_scale: float = MOE_SCALE) -> list[str]:
    argv = base_train_argv(training_cfg)

    # bool flags
    if research_kwargs.get("use_moe", False):
        argv += ["--use-moe"]
    if research_kwargs.get("use_perm", False):
        argv += ["--use-perm"]
    if research_kwargs.get("allow_replacement", False):
        argv += ["--allow-replacement"]
    if research_kwargs.get("use_remixed_linear", False):
        argv += ["--use-remixed-linear"]

    # scalar args
    scalar_map = {
        "num_experts": "--num-experts",
        "router_dim": "--router-dim",
        "target_dim": "--target-dim",
        "selection_mode": "--selection-mode",
        "context_dim": "--context-dim",
        "linear_basis_size": "--linear-basis-size",
    }
    for k, flag in scalar_map.items():
        if k in research_kwargs and research_kwargs[k] is not None:
            argv += [flag, str(research_kwargs[k])]

    # remixed linear gate controls
    remix_kwargs = research_kwargs.get("remixed_linear_kwargs", {})
    argv += ["--remix-use-basis-gate", str(int(bool(remix_kwargs.get("use_basis_gate", True))))]
    argv += ["--remix-use-output-gate", str(int(bool(remix_kwargs.get("use_output_gate", True))))]
    argv += ["--remix-use-context", str(int(bool(remix_kwargs.get("use_context", True))))]

    resolved_lrs = _resolve_research_lrs(training_cfg, research_kwargs, moe_scale)
    argv += ["--embedding-lr", str(resolved_lrs["embedding_lr"])]
    argv += ["--unembedding-lr", str(resolved_lrs["unembedding_lr"])]
    argv += ["--matrix-lr", str(resolved_lrs["matrix_lr"])]
    argv += ["--scalar-lr", str(resolved_lrs["scalar_lr"])]

    # Research-specific beta overrides (if provided)
    beta1 = float(research_kwargs.get("research_adam_beta1", training_cfg.get("adam_beta1", 0.8)))
    beta2 = float(research_kwargs.get("research_adam_beta2", training_cfg.get("adam_beta2", 0.95)))
    argv += ["--adam-beta1", str(beta1), "--adam-beta2", str(beta2)]

    warmup, warmdown, final_lr_frac = _resolve_schedule(training_cfg, research_kwargs)
    argv += [
        "--warmup-ratio", str(warmup),
        "--warmdown-ratio", str(warmdown),
        "--final-lr-frac", str(final_lr_frac),
    ]

    if bool(research_kwargs.get("research_use_pos_embed", research_kwargs.get("use_pos_embed", False))):
        argv += ["--use-pos-embed"]
    argv += ["--moe-use-abs-pos-embed", str(int(bool(research_kwargs.get("moe_use_abs_pos_embed", True))))]

    return argv


# For research sweeps keep sequence length and target dim fixed for comparability.
TRAINING_CONFIG['max_seq_len'] = 64
RESEARCH_GPT_KWARGS['target_dim'] = 64
# Ensure attention divisibility with target_dim=64
TRAINING_CONFIG['head_dim'] = 16


RESEARCH_RUN_KWARGS = {
    **RESEARCH_GPT_KWARGS,  # model keys
    "research_embedding_lr": 0.05,
    "research_unembedding_lr": 0.05,
    "research_matrix_lr": 0.05,
    "research_scaler_lr": 0.05,
    "research_adam_beta1": 0.8,
    "research_adam_beta2": 0.99,
    "research_one_cycle": True,
    "research_warmup": 0.3,
    # "moe_num_experts": 16,

}
research_argv = research_train_argv(TRAINING_CONFIG, RESEARCH_RUN_KWARGS, moe_scale=MOE_SCALE)


# research_argv = research_train_argv(TRAINING_CONFIG, RESEARCH_GPT_KWARGS, moe_scale=MOE_SCALE)
print(' '.join(research_argv))

# %%
# Run research training from notebook:
import runpy, sys
old_argv = sys.argv[:]
sys.argv = research_argv
try:
    runpy.run_module('scripts.base_train', run_name='__main__')
finally:
    sys.argv = old_argv

# %%
# import torch
# from nanochat.gpt import GPT, GPTConfig
# from nanochat.tokenizer import get_tokenizer # assuming repo provides these

# # Path to your checkpoint
# model_dir = "/kaggle/working/research_checkpoints/nb_d20_research_moe16_lr005/model_000050.pt"

# # 1. Build config with your provided arguments
# config = GPTConfig(
#     sequence_len=64,
#     vocab_size=32768,
#     n_layer=8,
#     n_head=4,
#     n_kv_head=4,
#     n_embd=64,

#     use_moe=True,
#     use_perm=False,
#     moe_num_experts=8,
#     moe_router_dim=64,
#     moe_embed_dim=64,
#     use_remix_linear=False,
#     remix_context_dim=64,
#     remix_basis_size=64,
#     remixed_linear_kwargs=None,

#     num_experts=8,
#     total_embed_dim=64,
#     router_dim=64,
#     capacity_factor=1.0,
#     use_sparse_top_k=False,
#     top_k=1,
#     routing_mode="token_choice",
#     context_window=-1,
#     causal=True,
#     use_expert_mlp=True,
#     use_output_projection=True,
#     use_expert_bias=False,
#     dropout=0.0,
#     use_shared_base=False,
#     shared_base_dim=128,
#     use_vocab_prior=False,
#     expert_residual=False,
#     allow_replacement=True,
#     use_embed_refine=False,
#     target_dim=64,
#     selection_mode="soft",
#     use_remixed_linear=False,
#     context_dim=64,
#     linear_basis_size=64,
#     use_pos_embed=False,
#     moe_use_abs_pos_embed=True,

#     router_context_window=-1,
#     router_causal=True,
#     router_num_heads=4,
#     router_num_queries=8,
#     router_n_layers=2,
#     router_use_vocab_prior=False,

#     window_pattern="SSSL",
# )

# # 2. Initialize model
# model = GPT(config)

# # 3. Load checkpoint
# checkpoint = torch.load(model_dir, map_location="cpu")
# print(checkpoint.keys())  # inspect to see where weights are stored

# # Adjust depending on checkpoint structure:
# if "model" in checkpoint:
#     model.load_state_dict(checkpoint["model"], strict=False)
# elif "state_dict" in checkpoint:
#     model.load_state_dict(checkpoint["state_dict"], strict=False)
# else:
#     model.load_state_dict(checkpoint, strict=False)

# model.eval()
# tokenizer = get_tokenizer()
# # 4. Generate text
# def generate_text(prompt, max_new_tokens=100):
#     input_ids = torch.tensor(tokenizer.encode(prompt), dtype=torch.long).unsqueeze(0)[0].tolist()
#     with torch.no_grad():
#         output_ids = list(model.generate(input_ids, max_tokens=max_new_tokens))
#         # model.generate(input_ids, max_new_tokens=max_new_tokens)
#     return tokenizer.decode(output_ids)
# # Example usage
# print(generate_text("Once upon a time"))

# %%
# print(generate_text("<|bos|>The capital of France is "))

# %%
# print(generate_text("The chemical symbol of gold is"))

# %%
# print(generate_text("If yesterday was Friday, then tomorrow will be"))

# %%
# print(generate_text("<|bos|>The opposite of hot is"))

# %%
# print(generate_text("<|bos|>The planets of the solar system are:"))

# %%
# print(generate_text("<|bos|>My favorite color is"))

# %%
# print(generate_text("<|bos|>If 5*x + 3 = 13, then x is"))

# %%
import torch._dynamo
torch._dynamo.disable()

# %%
from math import ceil

TRAINING_CONFIG = {
    # Logging/runtime
    'run': 'nb-base-train',
    # 'data_dir': None,#"/kaggle/working/dataset",
    'checkpoints_dir': "base_checkpoints",
    'device_type': '',  # ''=autodetect, or set 'cuda'/'cpu'/'mps'
    'compile': False, 

    # 'parallel': "dp",

    # Model
    'depth': 8, #20,
    'aspect_ratio': 64,
    'head_dim': 16, #128,
    'max_seq_len': 64,#2048,
    'window_pattern': 'SSSL',


    # Batch + training horizon
    'device_batch_size': 8,
    'total_batch_size': 524288//64,  # in tokens
    'training_tokens': 5000 * (524288//64),  # <-- edit this to control total training budget

    # Optimization
    'embedding_lr': 0.3,
    'unembedding_lr': 0.004,
    'weight_decay': 0.2,
    'matrix_lr': 0.02,
    'scalar_lr': 0.5,
    'adam_beta1': 0.8,
    'adam_beta2': 0.95,
    'warmup_ratio': 0.0,
    'warmdown_ratio': 0.5,
    'final_lr_frac': 0.0,
    "moe_use_abs_pos_embed": True,

    # Evaluation/checkpoint cadence
    'eval_every': 20,#250,
    'eval_tokens': 2 * 524288,
    'core_metric_every': -1,
    'core_metric_max_per_task': 500,
    'sample_every': 500,
    'save_every': 500,

    # Extras
    'resume_from_step': -1,
    'model_tag': 'nb_d20',
    'fp8': False,
    'fp8_recipe': 'tensorwise',
}


TRAINING_CONFIG['num_iterations'] = ceil(TRAINING_CONFIG['training_tokens'] / TRAINING_CONFIG['total_batch_size'])
print('Planned iterations:', TRAINING_CONFIG['num_iterations'])
print('Planned tokens   :', TRAINING_CONFIG['num_iterations'] * TRAINING_CONFIG['total_batch_size'])
print('CORE in training?:', TRAINING_CONFIG['core_metric_every'])

def base_train_argv(cfg: dict) -> list[str]:
    flag_map = {
        'run': '--run', 'device_type': '--device-type',
        'data_dir': '--data-dir', 'checkpoints_dir': '--checkpoints-dir',
        'depth': '--depth', 'aspect_ratio': '--aspect-ratio', 'head_dim': '--head-dim',
        'max_seq_len': '--max-seq-len', 'window_pattern': '--window-pattern',
        'num_iterations': '--num-iterations',
        'device_batch_size': '--device-batch-size', 'total_batch_size': '--total-batch-size',
        'embedding_lr': '--embedding-lr', 'unembedding_lr': '--unembedding-lr',
        'weight_decay': '--weight-decay', 'matrix_lr': '--matrix-lr', 'scalar_lr': '--scalar-lr',
        'adam_beta1': '--adam-beta1', 'adam_beta2': '--adam-beta2',
        'warmup_ratio': '--warmup-ratio', 'warmdown_ratio': '--warmdown-ratio', 'final_lr_frac': '--final-lr-frac',
        'resume_from_step': '--resume-from-step',
        'eval_every': '--eval-every', 'eval_tokens': '--eval-tokens',
        'core_metric_every': '--core-metric-every', 'core_metric_max_per_task': '--core-metric-max-per-task',
        'sample_every': '--sample-every', 'save_every': '--save-every',
        'model_tag': '--model-tag', 'fp8_recipe': '--fp8-recipe',
    }
    argv = ['scripts.base_train']
    
    # Handle boolean flags that don't take a value
    if cfg.get('fp8', False):
        argv.append('--fp8')
        
    # Handle the new compile flag (standard argparse boolean optional)
    if 'compile' in cfg:
        argv.append('--compile' if cfg['compile'] else '--no-compile')
    for k, flag in flag_map.items():
        if k in cfg:
            argv.extend([flag, str(cfg[k])])
    return argv
# Now train_argv will include '--no-compile' if cfg['compile'] is False
train_argv = base_train_argv(TRAINING_CONFIG)
print(' '.join(train_argv))
# Out:
# Planned iterations: 5000
# Planned tokens   : 40960000
# CORE in training?: -1
# scripts.base_train --no-compile --run nb-base-train --device-type  --checkpoints-dir base_checkpoints --depth 8 --aspect-ratio 64 --head-dim 16 --max-seq-len 64 --window-pattern SSSL --num-iterations 5000 --device-batch-size 8 --total-batch-size 8192 --embedding-lr 0.3 --unembedding-lr 0.004 --weight-decay 0.2 --matrix-lr 0.02 --scalar-lr 0.5 --adam-beta1 0.8 --adam-beta2 0.95 --warmup-ratio 0.0 --warmdown-ratio 0.5 --final-lr-frac 0.0 --resume-from-step -1 --eval-every 20 --eval-tokens 1048576 --core-metric-every -1 --core-metric-max-per-task 500 --sample-every 500 --save-every 500 --model-tag nb_d20 --fp8-recipe tensorwise

# %%
import copy
import csv
import glob
import itertools
import json
import os
import runpy
import sys
import time

from nanochat.common import get_base_dir
from nanochat.gpt import GPT, GPTConfig


def _strip_research_runtime_keys(research_kwargs: dict) -> dict:
    """Keep only model-relevant keys for GPT kwargs and silence research_* warning noise."""
    return {k: v for k, v in research_kwargs.items() if not k.startswith('research_')}


def _write_rows_tsv(rows: list[dict], out_tsv: str):
    if not rows:
        return
    fieldnames = list(rows[0].keys())
    with open(out_tsv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames, delimiter='	')
        writer.writeheader()
        writer.writerows(rows)
def estimate_model_params(train_cfg: dict, research_kwargs: dict, vocab_size: int = 32768) -> int:
    depth = int(train_cfg['depth'])
    head_dim = int(train_cfg['head_dim'])
    if research_kwargs.get('use_moe', False):
        model_dim = int(research_kwargs.get('target_dim', 64))
    else:
        base_dim = depth * int(train_cfg['aspect_ratio'])
        model_dim = ((base_dim + head_dim - 1) // head_dim) * head_dim
    n_head = model_dim // head_dim

    cfg = GPTConfig(
        sequence_len=int(train_cfg['max_seq_len']),
        vocab_size=vocab_size,
        n_layer=depth,
        n_head=n_head,
        n_kv_head=n_head,
        n_embd=model_dim,
        window_pattern=train_cfg.get('window_pattern', 'SSSL'),
        **research_to_gpt_kwargs(_strip_research_runtime_keys(research_kwargs)),
    )
    with __import__('torch').device('meta'):
        model = GPT(cfg)
    return sum(p.numel() for p in model.parameters())


def latest_meta_for_tag(model_tag: str):
    ckpt_dir = os.path.join(get_base_dir(), 'base_checkpoints', model_tag)
    metas = sorted(glob.glob(os.path.join(ckpt_dir, 'meta_*.json')))
    if not metas:
        return None
    with open(metas[-1], 'r', encoding='utf-8') as f:
        return json.load(f)


def _lr_variants():
    """Yield both shared-LR and separate-LR research override packs."""
    shared_values = [
        0.0005, 0.001, 0.0015, 0.002, 0.003, 0.004, 0.006, 0.008,
        0.01, 0.012, 0.015, 0.02, 0.025, 0.03, 0.04, 0.05
    ]
    for v in shared_values:
        yield 'shared', {
            'research_embedding_lr': v,
            'research_unembedding_lr': v,
            'research_matrix_lr': v,
            'research_scaler_lr': v,
        }
    
    separate_values = [
        # (embedding, unembedding, matrix, scaler)
        (0.04, 0.004, 0.03, 0.20),
        (0.03, 0.003, 0.02, 0.15),
        (0.025, 0.0025, 0.018, 0.12),
        (0.02, 0.002, 0.015, 0.10),
        (0.015, 0.0015, 0.012, 0.08),
        (0.01, 0.001, 0.008, 0.06),
        (0.008, 0.0008, 0.006, 0.05),
        (0.006, 0.0006, 0.004, 0.04),
    
        # more aggressive matrix-heavy variants
        (0.02, 0.002, 0.03, 0.08),
        (0.015, 0.0015, 0.025, 0.06),
    
        # higher scalar emphasis variants
        (0.02, 0.002, 0.015, 0.20),
        (0.015, 0.0015, 0.01, 0.15),
    
        # conservative low-LR variants
        (0.005, 0.0005, 0.003, 0.03),
        (0.003, 0.0003, 0.002, 0.02),
    ]

    for e_lr, u_lr, m_lr, s_lr in separate_values:
        yield 'separate', {
            'research_embedding_lr': e_lr,
            'research_unembedding_lr': u_lr,
            'research_matrix_lr': m_lr,
            'research_scaler_lr': s_lr,
        }


def make_experiment_grid(max_experiments: int | None = None) -> list[dict]:
    phase_defs = [
        # {'name': 'phase1_moe_only', 'use_moe': True,  'use_perm': False, 'use_remixed_linear': False},
        # {'name': 'phase2_moe_perm', 'use_moe': True,  'use_perm': True,  'use_remixed_linear': False},
        {'name': 'phase3_remixed',  'use_moe': False, 'use_perm': False, 'use_remixed_linear': True},
    ]

    base_axes = list(itertools.product(
        [1.0, 2.0, 3.0, 5.0, 8.0, 10.0],        # MOE scale
        [8, 16, 24, 32],                        # num_experts
        [0.0, 0.05, 0.1],                       # research_warmup
        [False, True],                          # research_one_cycle
        [0.8, 0.9],                             # research_adam_beta1
        [0.95, 0.99],                           # research_adam_beta2
    ))
    lr_axes = list(_lr_variants())

    experiments = []
    for phase in phase_defs:
        for i, (moe_scale, num_experts, warmup, one_cycle, b1, b2) in enumerate(base_axes):
            lr_mode, lr_pack = lr_axes[i % len(lr_axes)]
            exp_idx = len(experiments)
            k = exp_idx % 4
            experiments.append({
                'phase': phase['name'],
                'model_tag': f"auto_research_{exp_idx:04d}_{phase['name']}",
                'MOE_SCALE': moe_scale,
                'lr_mode': lr_mode,
                'research': {
                    'use_moe': phase['use_moe'],
                    'use_perm': phase['use_perm'],
                    'use_remixed_linear': phase['use_remixed_linear'],
                    'target_dim': 64,
                    'router_dim': 64,
                    'context_dim': 64,
                    'linear_basis_size': 64,
                    'num_experts': int(num_experts),
                    'selection_mode': 'soft',
                    'allow_replacement': True,
                    'research_warmup': float(warmup),
                    'research_one_cycle': bool(one_cycle),
                    'research_adam_beta1': float(b1),
                    'research_adam_beta2': float(b2),
                    'research_use_pos_embed': (k in [1, 3]),
                    'use_pos_embed': (k in [1, 3]),
                    'moe_use_abs_pos_embed': (k in [0, 2]),
                    **lr_pack,
                },
            })

            if max_experiments is not None and len(experiments) >= max_experiments:
                return experiments
    return experiments


AUTO_RESEARCH_OUT = 'research_sweep_results.tsv'

def run_auto_research_sweep(base_train_cfg: dict, out_tsv: str = AUTO_RESEARCH_OUT, max_experiments: int | None = None, flush_every: int = 20):
    rows = []
    experiments = make_experiment_grid(max_experiments=max_experiments)
    print(f"Planned experiments: {len(experiments)}")

    for i, exp in enumerate(experiments, start=1):
        train_cfg = copy.deepcopy(base_train_cfg)
        research_cfg = copy.deepcopy(exp['research'])

        # Fixed per your requirement for sweep comparability
        train_cfg['max_seq_len'] = 64
        train_cfg['num_iterations'] = 20
        train_cfg['model_tag'] = exp['model_tag']
        train_cfg['run'] = f"{base_train_cfg.get('run', 'nb')}-{exp['model_tag']}"

        model_params = estimate_model_params(train_cfg, research_cfg)
        argv = research_train_argv(train_cfg, research_cfg, moe_scale=exp['MOE_SCALE'])

        print(f"\n[{i}/{len(experiments)}] {exp['phase']} | tag={exp['model_tag']} | params={model_params:,} | lr_mode={exp['lr_mode']}")

        start = time.time()
        old_argv = sys.argv[:]
        sys.argv = argv
        status = 'ok'
        error_message = ''
        try:
            runpy.run_module('scripts.base_train', run_name='__main__')
        except Exception as e:
            status = 'error'
            error_message = repr(e)
            print(f"Run failed: {error_message}")
        finally:
            sys.argv = old_argv
        duration_s = round(time.time() - start, 2)

        meta = latest_meta_for_tag(exp['model_tag'])
        final_val_bpb = None if meta is None else meta.get('val_bpb')

        rows.append({
            'idx': i,
            'phase': exp['phase'],
            'model_tag': exp['model_tag'],
            'status': status,
            'duration_s': duration_s,
            'model_params': model_params,
            'val_bpb': final_val_bpb,
            'MOE_SCALE': exp['MOE_SCALE'],
            'lr_mode': exp['lr_mode'],
            'num_iterations': train_cfg['num_iterations'],
            'use_moe': research_cfg['use_moe'],
            'use_perm': research_cfg['use_perm'],
            'use_remixed_linear': research_cfg['use_remixed_linear'],
            'max_seq_len': train_cfg['max_seq_len'],
            'target_dim': research_cfg['target_dim'],
            'num_experts': research_cfg['num_experts'],
            'research_warmup': research_cfg['research_warmup'],
            'research_one_cycle': research_cfg['research_one_cycle'],
            'research_embedding_lr': research_cfg['research_embedding_lr'],
            'research_unembedding_lr': research_cfg['research_unembedding_lr'],
            'research_matrix_lr': research_cfg['research_matrix_lr'],
            'research_scaler_lr': research_cfg['research_scaler_lr'],
            'research_adam_beta1': research_cfg['research_adam_beta1'],
            'research_adam_beta2': research_cfg['research_adam_beta2'],
            'moe_use_abs_pos_embed': research_cfg['moe_use_abs_pos_embed'],
            'research_use_pos_embed': research_cfg['research_use_pos_embed'],
            'use_pos_embed': research_cfg.get('use_pos_embed', False),
            'error': error_message,
            'argv': ' '.join(argv),
        })

        if flush_every > 0 and (i % flush_every == 0):
            _write_rows_tsv(rows, out_tsv)
            print(f"Checkpoint save ({i} experiments): {out_tsv}")

    _write_rows_tsv(rows, out_tsv)
    print(f"Saved sweep log: {out_tsv}")
    return rows

# %%
# Examples:
# quick smoke run (still 20 iters each):
# rows = run_auto_research_sweep(TRAINING_CONFIG, max_experiments=6, flush_every=2)
# full larger sweep:
# rows = run_auto_research_sweep(TRAINING_CONFIG, max_experiments=None, flush_every=20)  # try 10/20/100
# rows[:2]
# Out:
# 2026-03-16 21:13:50,866 - nanochat.common - INFO - Distributed world size: 1
# 2026-03-16 21:13:50,867 - nanochat.common - WARNING - Peak flops undefined for: Tesla T4, MFU will show as 0%
# Planned experiments: 6
#
# [1/6] phase3_remixed | tag=auto_research_0000_phase3_remixed | params=106,905,106 | lr_mode=shared
#
#                                                        █████                █████
#                                                       ░░███                ░░███
#      ████████    ██████   ████████    ██████   ██████  ░███████    ██████  ███████
#     ░░███░░███  ░░░░░███ ░░███░░███  ███░░███ ███░░███ ░███░░███  ░░░░░███░░░███░
#      ░███ ░███   ███████  ░███ ░███ ░███ ░███░███ ░░░  ░███ ░███   ███████  ░███
#      ░███ ░███  ███░░███  ░███ ░███ ░███ ░███░███  ███ ░███ ░███  ███░░███  ░███ ███
#      ████ █████░░████████ ████ █████░░██████ ░░██████  ████ █████░░███████  ░░█████
#     ░░░░ ░░░░░  ░░░░░░░░ ░░░░ ░░░░░  ░░░░░░   ░░░░░░  ░░░░ ░░░░░  ░░░░░░░░   ░░░░░
#
# Autodetected device type: cuda
# GPU: Tesla T4 | Peak FLOPS (BF16): inf
# COMPUTE_DTYPE: torch.float32 (auto-detected: CUDA SM 75 (pre-Ampere, bf16 not supported, using fp32))
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# WARNING: Flash Attention 3 not available, using PyTorch SDPA fallback
# WARNING: Training will be less efficient without FA3
# WARNING: SDPA has no support for sliding window attention (window_pattern='SSSL'). Your GPU utilization will be terrible.
# WARNING: Recommend using --window-pattern L for full context attention without alternating sliding window patterns.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Vocab size: 32,768
# Model config:
# {
#   "sequence_len": 64,
#   "vocab_size": 32768,
#   "n_layer": 8,
#   "n_head": 4,
#   "n_kv_head": 4,
#   "n_embd": 64,
#   "use_moe": false,
#   "use_perm": false,
#   "moe_num_experts": 8,
#   "moe_router_dim": 64,
#   "moe_embed_dim": 64,
#   "use_remix_linear": true,
#   "remix_context_dim": 64,
#   "remix_basis_size": 64,
#   "remixed_linear_kwargs": {
#     "use_basis_gate": true,
#     "use_output_gate": true,
#     "use_context": true
#   },
#   "num_experts": 8,
#   "total_embed_dim": 64,
#   "router_dim": 64,
#   "capacity_factor": 1.0,
#   "use_sparse_top_k": false,
#   "top_k": 1,
#   "routing_mode": "token_choice",
#   "context_window": -1,
#   "causal": true,
#   "use_expert_mlp": true,
#   "use_output_projection": true,
#   "use_expert_bias": false,
#   "dropout": 0.0,
#   "use_shared_base": false,
#   "shared_base_dim": 128,
#   "use_vocab_prior": false,
#   "expert_residual": false,
#   "allow_replacement": true,
#   "use_embed_refine": false,
#   "target_dim": 64,
#   "selection_mode": "soft",
#   "use_remixed_linear": true,
#   "context_dim": 64,
#   "linear_basis_size": 64,
#   "use_pos_embed": false,
#   "moe_use_abs_pos_embed": true,
#   "router_context_window": -1,
#   "router_causal": true,
#   "router_num_heads": 4,
#   "router_num_queries": 8,
#   "router_n_layers": 2,
#   "router_use_vocab_prior": false,
#   "window_pattern": "SSSL"
# }
# Parameter counts:
# wte                     : 2,097,152
# wpe                     : 0
# value_embeds            : 8,388,608
# lm_head                 : 2,097,152
# transformer_matrices    : 954,368
# research                : 29,698
# scalars                 : 16
# total                   : 13,566,994
# Estimated FLOPs per token: 1.873307e+07
# Scaling LRs by 0.1250 for batch size 8,192 (reference: 524,288)
# Scaling weight decay from 0.200000 to 0.028909 for depth 8
# Scaling the LR for the AdamW parameters ∝1/√(64/768) = 3.464102
# Using user-provided number of iterations: 20
# Total number of training tokens: 163,840
# Tokens : Scaling params ratio: 0.05
# Total training FLOPs estimate: 3.069226e+12
# Using research scheduler: OneCycle-style LR multiplier
# Tokens / micro-batch / rank: 8 x 64 = 512
# Tokens / micro-batch: 512
# Total batch size 8,192 => gradient accumulation steps: 16
# Step 00000 | Validation bpb: 3.239188
# step 00000/00020 (0.00%) | loss: 10.397125 | lrm: 0.00 | lr(adamw:0.000e+00, muon:0.000e+00) | dt: 1581.75ms | tok/sec: 5,179 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00001/00020 (5.00%) | loss: 10.396931 | lrm: 1.00 | lr(adamw:1.542e-04, muon:6.221e-05) | dt: 1460.65ms | tok/sec: 5,608 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00002/00020 (10.00%) | loss: 10.395789 | lrm: 0.98 | lr(adamw:1.513e-04, muon:6.108e-05) | dt: 1446.90ms | tok/sec: 5,661 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00003/00020 (15.00%) | loss: 10.394237 | lrm: 0.95 | lr(adamw:1.465e-04, muon:5.912e-05) | dt: 1462.12ms | tok/sec: 5,602 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00004/00020 (20.00%) | loss: 10.392519 | lrm: 0.90 | lr(adamw:1.397e-04, muon:5.638e-05) | dt: 1445.26ms | tok/sec: 5,668 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00005/00020 (25.00%) | loss: 10.390380 | lrm: 0.85 | lr(adamw:1.312e-04, muon:5.295e-05) | dt: 1412.20ms | tok/sec: 5,800 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00006/00020 (30.00%) | loss: 10.388941 | lrm: 0.78 | lr(adamw:1.212e-04, muon:4.891e-05) | dt: 1423.48ms | tok/sec: 5,754 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00007/00020 (35.00%) | loss: 10.386672 | lrm: 0.71 | lr(adamw:1.099e-04, muon:4.437e-05) | dt: 1490.13ms | tok/sec: 5,497 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00008/00020 (40.00%) | loss: 10.384744 | lrm: 0.63 | lr(adamw:9.781e-05, muon:3.948e-05) | dt: 1470.27ms | tok/sec: 5,571 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00009/00020 (45.00%) | loss: 10.382898 | lrm: 0.55 | lr(adamw:8.511e-05, muon:3.435e-05) | dt: 1415.59ms | tok/sec: 5,786 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00010/00020 (50.00%) | loss: 10.381053 | lrm: 0.47 | lr(adamw:7.220e-05, muon:2.914e-05) | dt: 1427.53ms | tok/sec: 5,738 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00011/00020 (55.00%) | loss: 10.378596 | lrm: 0.38 | lr(adamw:5.943e-05, muon:2.398e-05) | dt: 1478.69ms | tok/sec: 5,540 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.02m | eta: 0.2m
# step 00012/00020 (60.00%) | loss: 10.376745 | lrm: 0.30 | lr(adamw:4.716e-05, muon:1.903e-05) | dt: 1466.73ms | tok/sec: 5,585 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.05m | eta: 0.2m
# step 00013/00020 (65.00%) | loss: 10.374913 | lrm: 0.23 | lr(adamw:3.573e-05, muon:1.442e-05) | dt: 1429.12ms | tok/sec: 5,732 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.07m | eta: 0.2m
# step 00014/00020 (70.00%) | loss: 10.373262 | lrm: 0.16 | lr(adamw:2.547e-05, muon:1.028e-05) | dt: 1499.89ms | tok/sec: 5,461 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.10m | eta: 0.1m
# step 00015/00020 (75.00%) | loss: 10.371832 | lrm: 0.11 | lr(adamw:1.665e-05, muon:6.718e-06) | dt: 1448.08ms | tok/sec: 5,657 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.12m | eta: 0.1m
# step 00016/00020 (80.00%) | loss: 10.370480 | lrm: 0.06 | lr(adamw:9.518e-06, muon:3.841e-06) | dt: 1443.54ms | tok/sec: 5,674 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.15m | eta: 0.1m
# step 00017/00020 (85.00%) | loss: 10.369474 | lrm: 0.03 | lr(adamw:4.280e-06, muon:1.727e-06) | dt: 1418.81ms | tok/sec: 5,773 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.17m | eta: 0.1m
# step 00018/00020 (90.00%) | loss: 10.368530 | lrm: 0.01 | lr(adamw:1.077e-06, muon:4.348e-07) | dt: 1424.47ms | tok/sec: 5,750 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.19m | eta: 0.0m
# step 00019/00020 (95.00%) | loss: 10.367854 | lrm: 0.00 | lr(adamw:0.000e+00, muon:0.000e+00) | dt: 1443.53ms | tok/sec: 5,674 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.22m | eta: 0.0m
# Step 00020 | Validation bpb: 3.227605
# <|bos|>The capital of France is almostFocus know in and other the same of our".
# The are doing are
# <|bos|>The chemical symbol of gold is almost Ill in their have been in and other the same of this a lot3
# <|bos|>If yesterday was Friday, then tomorrow will be able with have been in and for to be able we this that as the United
# <|bos|>The opposite of hot is almost Ill in and other the same of heat question with the same of the same
# <|bos|>The planets of the solar system are: are generally1 are generally1 have been in a bit into I am of the
# <|bos|>My favorite color is almost Ill in and other the same of heat question with the same of heat bike
# 2026-03-16 21:16:37,156 - nanochat.checkpoint_manager - INFO - Saved model parameters to: /root/.cache/nanochat/base_checkpoints/auto_research_0000_phase3_remixed/model_000020.pt
# 2026-03-16 21:16:37,157 - nanochat.checkpoint_manager - INFO - Saved metadata to: /root/.cache/nanochat/base_checkpoints/auto_research_0000_phase3_remixed/meta_000020.json
# <|bos|>If 5*x + 3 = 13, then x is almost certainly consistent fasc you ever by abnormal3 with the same, but a lot
# 2026-03-16 21:16:37,340 - nanochat.checkpoint_manager - INFO - Saved optimizer state to: /root/.cache/nanochat/base_checkpoints/auto_research_0000_phase3_remixed/optim_000020_rank0.pt
# 2026-03-16 21:16:37,402 - nanochat.common - INFO - Distributed world size: 1
# 2026-03-16 21:16:37,403 - nanochat.common - WARNING - Peak flops undefined for: Tesla T4, MFU will show as 0%
# Peak memory usage: 2830.05MiB
# Total training time: 0.22m
# Minimum validation bpb: 3.227605
#
# [2/6] phase3_remixed | tag=auto_research_0001_phase3_remixed | params=106,937,874 | lr_mode=shared
#
#                                                        █████                █████
#                                                       ░░███                ░░███
#      ████████    ██████   ████████    ██████   ██████  ░███████    ██████  ███████
#     ░░███░░███  ░░░░░███ ░░███░░███  ███░░███ ███░░███ ░███░░███  ░░░░░███░░░███░
#      ░███ ░███   ███████  ░███ ░███ ░███ ░███░███ ░░░  ░███ ░███   ███████  ░███
#      ░███ ░███  ███░░███  ░███ ░███ ░███ ░███░███  ███ ░███ ░███  ███░░███  ░███ ███
#      ████ █████░░████████ ████ █████░░██████ ░░██████  ████ █████░░███████  ░░█████
#     ░░░░ ░░░░░  ░░░░░░░░ ░░░░ ░░░░░  ░░░░░░   ░░░░░░  ░░░░ ░░░░░  ░░░░░░░░   ░░░░░
#
# Autodetected device type: cuda
# GPU: Tesla T4 | Peak FLOPS (BF16): inf
# COMPUTE_DTYPE: torch.float32 (auto-detected: CUDA SM 75 (pre-Ampere, bf16 not supported, using fp32))
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# WARNING: Flash Attention 3 not available, using PyTorch SDPA fallback
# WARNING: Training will be less efficient without FA3
# WARNING: SDPA has no support for sliding window attention (window_pattern='SSSL'). Your GPU utilization will be terrible.
# WARNING: Recommend using --window-pattern L for full context attention without alternating sliding window patterns.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Vocab size: 32,768
# Model config:
# {
#   "sequence_len": 64,
#   "vocab_size": 32768,
#   "n_layer": 8,
#   "n_head": 4,
#   "n_kv_head": 4,
#   "n_embd": 64,
#   "use_moe": false,
#   "use_perm": false,
#   "moe_num_experts": 8,
#   "moe_router_dim": 64,
#   "moe_embed_dim": 64,
#   "use_remix_linear": true,
#   "remix_context_dim": 64,
#   "remix_basis_size": 64,
#   "remixed_linear_kwargs": {
#     "use_basis_gate": true,
#     "use_output_gate": true,
#     "use_context": true
#   },
#   "num_experts": 8,
#   "total_embed_dim": 64,
#   "router_dim": 64,
#   "capacity_factor": 1.0,
#   "use_sparse_top_k": false,
#   "top_k": 1,
#   "routing_mode": "token_choice",
#   "context_window": -1,
#   "causal": true,
#   "use_expert_mlp": true,
#   "use_output_projection": true,
#   "use_expert_bias": false,
#   "dropout": 0.0,
#   "use_shared_base": false,
#   "shared_base_dim": 128,
#   "use_vocab_prior": false,
#   "expert_residual": false,
#   "allow_replacement": true,
#   "use_embed_refine": false,
#   "target_dim": 64,
#   "selection_mode": "soft",
#   "use_remixed_linear": true,
#   "context_dim": 64,
#   "linear_basis_size": 64,
#   "use_pos_embed": true,
#   "moe_use_abs_pos_embed": false,
#   "router_context_window": -1,
#   "router_causal": true,
#   "router_num_heads": 4,
#   "router_num_queries": 8,
#   "router_n_layers": 2,
#   "router_use_vocab_prior": false,
#   "window_pattern": "SSSL"
# }
# Parameter counts:
# wte                     : 2,097,152
# wpe                     : 4,096
# value_embeds            : 8,388,608
# lm_head                 : 2,097,152
# transformer_matrices    : 954,368
# research                : 29,698
# scalars                 : 16
# total                   : 13,571,090
# Estimated FLOPs per token: 1.873307e+07
# Scaling LRs by 0.1250 for batch size 8,192 (reference: 524,288)
# Scaling weight decay from 0.200000 to 0.028909 for depth 8
# Scaling the LR for the AdamW parameters ∝1/√(64/768) = 3.464102
# Using user-provided number of iterations: 20
# Total number of training tokens: 163,840
# Tokens : Scaling params ratio: 0.05
# Total training FLOPs estimate: 3.069226e+12
# Using research scheduler: OneCycle-style LR multiplier
# Tokens / micro-batch / rank: 8 x 64 = 512
# Tokens / micro-batch: 512
# Total batch size 8,192 => gradient accumulation steps: 16
# Step 00000 | Validation bpb: 3.239226
# step 00000/00020 (0.00%) | loss: 10.397106 | lrm: 0.00 | lr(adamw:0.000e+00, muon:0.000e+00) | dt: 1567.06ms | tok/sec: 5,227 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00001/00020 (5.00%) | loss: 10.396938 | lrm: 1.00 | lr(adamw:3.083e-04, muon:1.244e-04) | dt: 1417.12ms | tok/sec: 5,780 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00002/00020 (10.00%) | loss: 10.394415 | lrm: 0.98 | lr(adamw:3.027e-04, muon:1.222e-04) | dt: 1493.82ms | tok/sec: 5,483 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00003/00020 (15.00%) | loss: 10.390310 | lrm: 0.95 | lr(adamw:2.930e-04, muon:1.182e-04) | dt: 1476.19ms | tok/sec: 5,549 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00004/00020 (20.00%) | loss: 10.385989 | lrm: 0.90 | lr(adamw:2.794e-04, muon:1.128e-04) | dt: 1476.55ms | tok/sec: 5,548 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00005/00020 (25.00%) | loss: 10.380647 | lrm: 0.85 | lr(adamw:2.624e-04, muon:1.059e-04) | dt: 1424.79ms | tok/sec: 5,749 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00006/00020 (30.00%) | loss: 10.375924 | lrm: 0.78 | lr(adamw:2.424e-04, muon:9.781e-05) | dt: 1496.39ms | tok/sec: 5,474 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00007/00020 (35.00%) | loss: 10.369793 | lrm: 0.71 | lr(adamw:2.199e-04, muon:8.875e-05) | dt: 1490.88ms | tok/sec: 5,494 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00008/00020 (40.00%) | loss: 10.364523 | lrm: 0.63 | lr(adamw:1.956e-04, muon:7.895e-05) | dt: 1415.12ms | tok/sec: 5,788 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00009/00020 (45.00%) | loss: 10.359394 | lrm: 0.55 | lr(adamw:1.702e-04, muon:6.870e-05) | dt: 1499.97ms | tok/sec: 5,461 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00010/00020 (50.00%) | loss: 10.354226 | lrm: 0.47 | lr(adamw:1.444e-04, muon:5.828e-05) | dt: 1441.19ms | tok/sec: 5,684 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00011/00020 (55.00%) | loss: 10.347902 | lrm: 0.38 | lr(adamw:1.189e-04, muon:4.797e-05) | dt: 1459.86ms | tok/sec: 5,611 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.02m | eta: 0.2m
# step 00012/00020 (60.00%) | loss: 10.342491 | lrm: 0.30 | lr(adamw:9.431e-05, muon:3.806e-05) | dt: 1454.49ms | tok/sec: 5,632 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.05m | eta: 0.2m
# step 00013/00020 (65.00%) | loss: 10.336656 | lrm: 0.23 | lr(adamw:7.146e-05, muon:2.884e-05) | dt: 1424.08ms | tok/sec: 5,752 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.07m | eta: 0.2m
# step 00014/00020 (70.00%) | loss: 10.331976 | lrm: 0.16 | lr(adamw:5.093e-05, muon:2.056e-05) | dt: 1409.80ms | tok/sec: 5,810 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.10m | eta: 0.1m
# step 00015/00020 (75.00%) | loss: 10.327443 | lrm: 0.11 | lr(adamw:3.329e-05, muon:1.344e-05) | dt: 1421.94ms | tok/sec: 5,761 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.12m | eta: 0.1m
# step 00016/00020 (80.00%) | loss: 10.323469 | lrm: 0.06 | lr(adamw:1.904e-05, muon:7.683e-06) | dt: 1442.60ms | tok/sec: 5,678 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.14m | eta: 0.1m
# step 00017/00020 (85.00%) | loss: 10.319823 | lrm: 0.03 | lr(adamw:8.559e-06, muon:3.455e-06) | dt: 1426.16ms | tok/sec: 5,744 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.17m | eta: 0.1m
# step 00018/00020 (90.00%) | loss: 10.316324 | lrm: 0.01 | lr(adamw:2.155e-06, muon:8.697e-07) | dt: 1408.56ms | tok/sec: 5,815 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.19m | eta: 0.0m
# step 00019/00020 (95.00%) | loss: 10.313636 | lrm: 0.00 | lr(adamw:0.000e+00, muon:0.000e+00) | dt: 1457.21ms | tok/sec: 5,621 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.22m | eta: 0.0m
# Step 00020 | Validation bpb: 3.206380
# <|bos|>The capital of France is a
#
#
#
#  have. ThisThe not. The.
#  be in
#
# <|bos|>The chemical symbol of gold is a. The have. ThisThe. The a.
#  be in the.
# <|bos|>If yesterday was Friday, then tomorrow will be.
#  their. It 20 a.. The. The. This. The
# <|bos|>The opposite of hot isTheI. The do to beThe. The a. This be in the
# <|bos|>The planets of the solar system are:. The. This a a. The. The be in the. The.
# <|bos|>My favorite color is aThe
#
#
#
#  The. ThisThe 20 a. The be.
# 2026-03-16 21:19:23,462 - nanochat.checkpoint_manager - INFO - Saved model parameters to: /root/.cache/nanochat/base_checkpoints/auto_research_0001_phase3_remixed/model_000020.pt
# 2026-03-16 21:19:23,463 - nanochat.checkpoint_manager - INFO - Saved metadata to: /root/.cache/nanochat/base_checkpoints/auto_research_0001_phase3_remixed/meta_000020.json
# <|bos|>If 5*x + 3 = 13, then x is a.
#  be can be. The. The. The. The. This
# 2026-03-16 21:19:23,631 - nanochat.checkpoint_manager - INFO - Saved optimizer state to: /root/.cache/nanochat/base_checkpoints/auto_research_0001_phase3_remixed/optim_000020_rank0.pt
# 2026-03-16 21:19:23,698 - nanochat.common - INFO - Distributed world size: 1
# 2026-03-16 21:19:23,699 - nanochat.common - WARNING - Peak flops undefined for: Tesla T4, MFU will show as 0%
# Peak memory usage: 2982.12MiB
# Total training time: 0.22m
# Minimum validation bpb: 3.206380
# Checkpoint save (2 experiments): research_sweep_results.tsv
#
# [3/6] phase3_remixed | tag=auto_research_0002_phase3_remixed | params=106,905,106 | lr_mode=shared
#
#                                                        █████                █████
#                                                       ░░███                ░░███
#      ████████    ██████   ████████    ██████   ██████  ░███████    ██████  ███████
#     ░░███░░███  ░░░░░███ ░░███░░███  ███░░███ ███░░███ ░███░░███  ░░░░░███░░░███░
#      ░███ ░███   ███████  ░███ ░███ ░███ ░███░███ ░░░  ░███ ░███   ███████  ░███
#      ░███ ░███  ███░░███  ░███ ░███ ░███ ░███░███  ███ ░███ ░███  ███░░███  ░███ ███
#      ████ █████░░████████ ████ █████░░██████ ░░██████  ████ █████░░███████  ░░█████
#     ░░░░ ░░░░░  ░░░░░░░░ ░░░░ ░░░░░  ░░░░░░   ░░░░░░  ░░░░ ░░░░░  ░░░░░░░░   ░░░░░
#
# Autodetected device type: cuda
# GPU: Tesla T4 | Peak FLOPS (BF16): inf
# COMPUTE_DTYPE: torch.float32 (auto-detected: CUDA SM 75 (pre-Ampere, bf16 not supported, using fp32))
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# WARNING: Flash Attention 3 not available, using PyTorch SDPA fallback
# WARNING: Training will be less efficient without FA3
# WARNING: SDPA has no support for sliding window attention (window_pattern='SSSL'). Your GPU utilization will be terrible.
# WARNING: Recommend using --window-pattern L for full context attention without alternating sliding window patterns.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Vocab size: 32,768
# Model config:
# {
#   "sequence_len": 64,
#   "vocab_size": 32768,
#   "n_layer": 8,
#   "n_head": 4,
#   "n_kv_head": 4,
#   "n_embd": 64,
#   "use_moe": false,
#   "use_perm": false,
#   "moe_num_experts": 8,
#   "moe_router_dim": 64,
#   "moe_embed_dim": 64,
#   "use_remix_linear": true,
#   "remix_context_dim": 64,
#   "remix_basis_size": 64,
#   "remixed_linear_kwargs": {
#     "use_basis_gate": true,
#     "use_output_gate": true,
#     "use_context": true
#   },
#   "num_experts": 8,
#   "total_embed_dim": 64,
#   "router_dim": 64,
#   "capacity_factor": 1.0,
#   "use_sparse_top_k": false,
#   "top_k": 1,
#   "routing_mode": "token_choice",
#   "context_window": -1,
#   "causal": true,
#   "use_expert_mlp": true,
#   "use_output_projection": true,
#   "use_expert_bias": false,
#   "dropout": 0.0,
#   "use_shared_base": false,
#   "shared_base_dim": 128,
#   "use_vocab_prior": false,
#   "expert_residual": false,
#   "allow_replacement": true,
#   "use_embed_refine": false,
#   "target_dim": 64,
#   "selection_mode": "soft",
#   "use_remixed_linear": true,
#   "context_dim": 64,
#   "linear_basis_size": 64,
#   "use_pos_embed": false,
#   "moe_use_abs_pos_embed": true,
#   "router_context_window": -1,
#   "router_causal": true,
#   "router_num_heads": 4,
#   "router_num_queries": 8,
#   "router_n_layers": 2,
#   "router_use_vocab_prior": false,
#   "window_pattern": "SSSL"
# }
# Parameter counts:
# wte                     : 2,097,152
# wpe                     : 0
# value_embeds            : 8,388,608
# lm_head                 : 2,097,152
# transformer_matrices    : 954,368
# research                : 29,698
# scalars                 : 16
# total                   : 13,566,994
# Estimated FLOPs per token: 1.873307e+07
# Scaling LRs by 0.1250 for batch size 8,192 (reference: 524,288)
# Scaling weight decay from 0.200000 to 0.028909 for depth 8
# Scaling the LR for the AdamW parameters ∝1/√(64/768) = 3.464102
# Using user-provided number of iterations: 20
# Total number of training tokens: 163,840
# Tokens : Scaling params ratio: 0.05
# Total training FLOPs estimate: 3.069226e+12
# Using research scheduler: OneCycle-style LR multiplier
# Tokens / micro-batch / rank: 8 x 64 = 512
# Tokens / micro-batch: 512
# Total batch size 8,192 => gradient accumulation steps: 16
# Step 00000 | Validation bpb: 3.239188
# step 00000/00020 (0.00%) | loss: 10.397125 | lrm: 0.00 | lr(adamw:0.000e+00, muon:0.000e+00) | dt: 1550.77ms | tok/sec: 5,282 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00001/00020 (5.00%) | loss: 10.396931 | lrm: 1.00 | lr(adamw:4.625e-04, muon:1.866e-04) | dt: 1451.88ms | tok/sec: 5,642 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00002/00020 (10.00%) | loss: 10.393585 | lrm: 0.98 | lr(adamw:4.540e-04, muon:1.832e-04) | dt: 1445.59ms | tok/sec: 5,666 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00003/00020 (15.00%) | loss: 10.388612 | lrm: 0.95 | lr(adamw:4.395e-04, muon:1.774e-04) | dt: 1470.49ms | tok/sec: 5,570 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00004/00020 (20.00%) | loss: 10.382738 | lrm: 0.90 | lr(adamw:4.191e-04, muon:1.692e-04) | dt: 1471.70ms | tok/sec: 5,566 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00005/00020 (25.00%) | loss: 10.375406 | lrm: 0.85 | lr(adamw:3.936e-04, muon:1.588e-04) | dt: 1510.48ms | tok/sec: 5,423 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00006/00020 (30.00%) | loss: 10.369770 | lrm: 0.78 | lr(adamw:3.635e-04, muon:1.467e-04) | dt: 1475.32ms | tok/sec: 5,552 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 1 | total time: 0.00m
# step 00007/00020 (35.00%) | loss: 10.361241 | lrm: 0.71 | lr(adamw:3.298e-04, muon:1.331e-04) | dt: 1483.29ms | tok/sec: 5,522 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00008/00020 (40.00%) | loss: 10.353928 | lrm: 0.63 | lr(adamw:2.934e-04, muon:1.184e-04) | dt: 1452.18ms | tok/sec: 5,641 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00009/00020 (45.00%) | loss: 10.346549 | lrm: 0.55 | lr(adamw:2.553e-04, muon:1.031e-04) | dt: 1423.49ms | tok/sec: 5,754 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00010/00020 (50.00%) | loss: 10.339010 | lrm: 0.47 | lr(adamw:2.166e-04, muon:8.741e-05) | dt: 1433.20ms | tok/sec: 5,715 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.00m
# step 00011/00020 (55.00%) | loss: 10.329872 | lrm: 0.38 | lr(adamw:1.783e-04, muon:7.195e-05) | dt: 1428.04ms | tok/sec: 5,736 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.02m | eta: 0.2m
# step 00012/00020 (60.00%) | loss: 10.322364 | lrm: 0.30 | lr(adamw:1.415e-04, muon:5.710e-05) | dt: 1485.42ms | tok/sec: 5,514 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.05m | eta: 0.2m
# step 00013/00020 (65.00%) | loss: 10.315037 | lrm: 0.23 | lr(adamw:1.072e-04, muon:4.326e-05) | dt: 1432.62ms | tok/sec: 5,718 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.07m | eta: 0.2m
# step 00014/00020 (70.00%) | loss: 10.308305 | lrm: 0.16 | lr(adamw:7.640e-05, muon:3.083e-05) | dt: 1416.25ms | tok/sec: 5,784 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 2 | total time: 0.10m | eta: 0.1m
# step 00015/00020 (75.00%) | loss: 10.302082 | lrm: 0.11 | lr(adamw:4.994e-05, muon:2.015e-05) | dt: 1443.82ms | tok/sec: 5,673 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.12m | eta: 0.1m
# step 00016/00020 (80.00%) | loss: 10.296400 | lrm: 0.06 | lr(adamw:2.855e-05, muon:1.152e-05) | dt: 1458.93ms | tok/sec: 5,615 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.14m | eta: 0.1m
# step 00017/00020 (85.00%) | loss: 10.292046 | lrm: 0.03 | lr(adamw:1.284e-05, muon:5.182e-06) | dt: 1445.40ms | tok/sec: 5,667 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.17m | eta: 0.1m
# step 00018/00020 (90.00%) | loss: 10.287862 | lrm: 0.01 | lr(adamw:3.232e-06, muon:1.305e-06) | dt: 1453.59ms | tok/sec: 5,635 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.19m | eta: 0.0m
# step 00019/00020 (95.00%) | loss: 10.284774 | lrm: 0.00 | lr(adamw:0.000e+00, muon:0.000e+00) | dt: 1481.83ms | tok/sec: 5,528 | bf16_mfu: 0.00 | epoch: 1 pq: 0 rg: 3 | total time: 0.22m | eta: 0.0m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_55/1941494988.py in <cell line: 0>()
#       1 # Examples:
#       2 # quick smoke run (still 20 iters each):
# ----> 3 rows = run_auto_research_sweep(TRAINING_CONFIG, max_experiments=6, flush_every=2)
#       4 # full larger sweep:
#       5 # rows = run_auto_research_sweep(TRAINING_CONFIG, max_experiments=None, flush_every=20)  # try 10/20/100
#
# /tmp/ipykernel_55/3117846196.py in run_auto_research_sweep(base_train_cfg, out_tsv, max_experiments, flush_every)
#     190         error_message = ''
#     191         try:
# --> 192             runpy.run_module('scripts.base_train', run_name='__main__')
#     193         except Exception as e:
#     194             status = 'error'
#
# /usr/lib/python3.12/runpy.py in run_module(mod_name, init_globals, run_name, alter_sys)
#
# /usr/lib/python3.12/runpy.py in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#
# /kaggle/working/nanochat/scripts/base_train.py in <module>
#     537         eval_steps = args.eval_tokens // (args.device_batch_size * args.max_seq_len * ddp_world_size)
#     538         with disable_fp8(model):
# --> 539             val_bpb = evaluate_bpb(model, val_loader, eval_steps, token_bytes)
#     540         print0(f"Step {step:05d} | Validation bpb: {val_bpb:.6f}")
#     541         if val_bpb < min_val_bpb:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /kaggle/working/nanochat/nanochat/loss_eval.py in evaluate_bpb(model, batches, steps, token_bytes)
#      31     for _ in range(steps):
#      32         x, y = next(batch_iter)
# ---> 33         loss2d = model(x, y, loss_reduction='none') # (B, T)
#      34         loss2d = loss2d.view(-1) # flatten
#      35         y = y.view(-1) # flatten
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /kaggle/working/nanochat/nanochat/gpt.py in forward(self, idx, targets, kv_cache, loss_reduction)
#    1017             ve = self.value_embeds[str(i)](idx).to(x.dtype) if str(i) in self.value_embeds else None
#    1018             if self.use_remix_linear:
# -> 1019                 x = block(x, ve, cos_sin, self.window_sizes[i], kv_cache, context_state=context_state)
#    1020             else:
#    1021                 x = block(x, ve, cos_sin, self.window_sizes[i], kv_cache)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /kaggle/working/nanochat/nanochat/gpt.py in forward(self, x, ve, cos_sin, window_size, kv_cache, context_state)
#     482
#     483     def forward(self, x, ve, cos_sin, window_size, kv_cache, context_state):
# --> 484         x = x + self.attn(norm(x), ve, cos_sin, window_size, kv_cache, context_state)
#     485         x = x + self.ffwd(norm(x), context_state)
#     486         return x
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /kaggle/working/nanochat/nanochat/gpt.py in forward(self, x, ve, cos_sin, window_size, kv_cache, context_state)
#     442     def forward(self, x, ve, cos_sin, window_size, kv_cache, context_state):
#     443         B, T, C = x.size()
# --> 444         q = self.c_q(x, context_state).view(B, T, self.n_head, self.head_dim)
#     445         k = self.c_k(x, context_state).view(B, T, self.n_kv_head, self.head_dim)
#     446         v = self.c_v(x, context_state).view(B, T, self.n_kv_head, self.head_dim)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /kaggle/working/nanochat/nanochat/gpt.py in forward(self, x, context_state)
#     405         # Linear layer expects weight matching input, and return value added with bias
#     406         pre_output = F.linear(h_gated, self.template_mixing.to(dtype=dtype))
# --> 407         return (pre_output * gate_out + self.bias.to(dtype=dtype)).to(dtype=dtype)
#     408
#     409
#
# KeyboardInterrupt:
